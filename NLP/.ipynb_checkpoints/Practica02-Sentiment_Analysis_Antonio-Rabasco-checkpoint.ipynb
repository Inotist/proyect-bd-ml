# %% [markdown]
# # Práctica del módulo NLP

# %%
import pandas as pd
import matplotlib.pyplot as plt

import re
from collections import Counter

from spacy.lang.es.stop_words import STOP_WORDS

import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel, CoherenceModel

from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence

import spacy
import lemminflect
spacy_lemmas = spacy.load('en_core_web_sm')

# %%
aiv5 = pd.read_csv("Amazon_Instant_Video_5.csv")
a5 = pd.read_csv("Automotive_5.csv")
dm5 = pd.read_csv("Digital_Music_5.csv")
mi5 = pd.read_csv("Musical_Instruments_5.csv")
plg5 = pd.read_csv("Patio_Lawn_and_Garden_5.csv")

reviews = pd.concat([aiv5,a5,dm5,mi5,plg5], ignore_index=True).dropna(subset=['reviewText']).sample(frac=1)
reviews.head()
# Out:
#            reviewerID        asin  \
# 7904    ADSWHY3431SD7  B004263SAM
# 9927   A354ZN03NP2ZK8  B00DN15JWW
# 12174   A5SBPZ1KHWX5Y  B0050SFZBG
# 21935  A3AL8GQ69QE7WN  B000000OQW
# 592    A3E2158X66LFMI  B00F55HIRI
#
#                                            reviewerName  helpful  \
# 7904                                      Sadcelticlady   [0, 0]
# 9927   William J. Meegan "Never let another do for y...   [0, 0]
# 12174                                           jwm1941   [0, 0]
# 21935                                       Jason Stein  [9, 12]
# 592                                                Mery   [1, 2]
#
#                                               reviewText  overall  \
# 7904   Helen murres is a fine actress ! This series n...        5
# 9927   Series like this I find educational as well as...        5
# 12174  This tool is excellent at performing the job f...        4
# 21935  Of the two Edie Brickell and the New Bohemians...        5
# 592    The show still has plenty with the hot origina...        5
#
#                                                  summary  unixReviewTime  \
# 7904                                      Great series !      1388448000
# 9927   Amazing series discussing very interesting psy...      1388793600
# 12174                                   VERY USEFUL TOOL      1392595200
# 21935                                Great College Rock.       953251200
# 592    Only thing I didn't like was that Rebecca left...      1404172800
#
#         reviewTime
# 7904   12 31, 2013
# 9927    01 4, 2014
# 12174  02 17, 2014
# 21935  03 17, 2000
# 592     07 1, 2014

# %% [markdown]
# # 2. Análisis de sentimiento

# %% [markdown]
# Me traigo mi función de preprocesado de textos y la amplío con nuevas funciones (lemmatizers, ngrams...)

# %%
def preprocess_texts(texts, **kwargs):
    
    processed_texts = [] # Aquí me guardaré los textos procesados en forma de lista
    
    # Para el autocorrector que se aplica más abajo utilizaré todo el texto de mi corpus
    if 'auto_correct' in kwargs and kwargs['auto_correct']:
        full_text = " ".join([text for text in texts])
    
    for text in texts:
        
        tokens = [] # Aquí se guardan los tokens que conforman cada texto
        
        # Comenzando con el preprocesado completo de gensim.utils.simple_preprocess()
        if 'simple_gensim' in kwargs and kwargs['simple_gensim']:
            rawtokens = [token for token in gensim.utils.simple_preprocess(text)]
            
        # Si decido aplicar un lemmatizer como split inicial
        elif 'lemmatizer' in kwargs:
            lemmas = kwargs['lemmatizer'](text)
            rawtokens = [token._.lemma() for token in lemmas]
            
        # Hago un split y utilizo tan solo mi preprocesado adicional
        else: rawtokens = text.split()
        
        # Aplico reglas adicionales de preprocesado.
        for token in rawtokens:
            if 'lower' in kwargs and kwargs['lower']: token = token.lower()
            if 'only_alpha' in kwargs and kwargs['only_alpha']: token = re.sub('[^a-zA-Z]+', '', token)
            if 'stop_words' in kwargs and token in kwargs.get('stop_words'): token = None

            if token: tokens.append(token)
                
        # Aplico mi corrector ortográfico al texto preprocesado.
        if 'auto_correct' in kwargs and kwargs['auto_correct']:
            for ix in range(len(tokens)):
                tokens[ix] = correct(tokens[ix], full_text, kwargs['auto_correct'])
                
        # Genero N-Gramas
        if 'ngrams' in kwargs:
            
            ngrams = [] # Aquí guardaré los ngramas que reemplazarán a la lista de tokens
            
            # Se puede utilizar una lista de varios ngramas
            if type(kwargs['ngrams']) is list or type(kwargs['ngrams']) is tuple:
                for ngram in kwargs['ngrams']:
                    for i in range(len(tokens)-ngram):
                        ngrams.append(" ".join(tokens[i:i+ngram]))
            
            # También se puede indicar un valor entero como única medida para el ngrama
            else:
                for i in range(len(tokens)-kwargs['ngrams']):
                    ngrams.append(" ".join(tokens[i:i+kwargs['ngrams']]))
                
            tokens = ngrams
        
        processed_texts.append(tokens)
        
    return processed_texts

# %%
# Con steps_away indico el número máximo de modificaciones que se realizarán para buscar una corrección.
def correct(word, text, steps_away=1):
    counts = Counter(text)
    
    candidates = [w for w in edits(word, steps=steps_away) if w in text or w is word]
    
    return max(candidates, key=lambda w: counts[w] / len(text))

# %%
def edits(word, steps=1):
    
    words = [word]
    
    for step in range(steps):
        
        new_words = []
        
        for word in words:
            letters    = 'abcdefghijklmnopqrstuvwxyz'
            splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
            deletes    = [L + R[1:]                 for L, R in splits if R]
            transposes = [L + R[1] + R[0] + R[2:]   for L, R in splits if len(R)>1]
            replaces   = [L + c + R[1:]             for L, R in splits if R for c in letters]
            inserts    = [L + c + R                 for L, R in splits for c in letters]
            
            new_words += list(set(deletes + transposes + replaces + inserts))

        words += list(set(new_words))
    
    return words

# %%
preprocess_texts(reviews.reviewText, lemmatizer=spacy_lemmas)
# Out:
# [['Helen',
#   'murre',
#   'be',
#   'a',
#   'fine',
#   'actress',
#   '!',
#   'This',
#   'series',
#   'never',
#   'grow',
#   'old',
#   '!',
#   'Have',
#   'enjoy',
#   'it',
#   'over',
#   'and',
#   'over',
#   'again',
#   '.'],
#  ['Series',
#   'like',
#   'this',
#   'I',
#   'find',
#   'educational',
#   'as',
#   'well',
#   'as',
#   'be',
#   'entertaining',
#   '.',
#   ' ',
#   'I',
#   'have',
#   'not',
#   'find',
#   'one',
#   'episode',
#   'to',
#   'be',
#   'boring',
#   '.',
#   ' ',
#   'The',
#   'idea',
#   'be',
#   'interestingly',
#   'work',
#   'out',
#   'each',
#   'week',
#   'in',
#   'a',
#   'mere',
#   '43',
#   'minute',
#   '.'],
#  ['This',
#   'tool',
#   'be',
#   'excellent',
#   'at',
#   'perform',
#   'the',
#   'job',
#   'for',
#   'which',
#   'it',
#   'be',
#   'design',
#   ':',
#   'remove',
#   'hose',
#   'connection',
#   '.',
#   'I',
#   'would',
#   'only',
#   'caution',
#   'that',
#   'you',
#   'take',
#   'care',
#   'to',
#   'observe',
#   'the',
#   'extremely',
#   'SHARP',
#   'point',
#   '.',
#   'However',
#   ',',
#   'the',
#   '&',
#   '#',
#   '34;sharp',
#   'point&e',
#   ';',
#   'be',
#   'one',
#   'of',
#   'the',
#   'major',
#   'reason',
#   'it',
#   'work',
#   'so',
#   'well',
#   '.'],
#  ['Of',
#   'the',
#   'two',
#   'Edie',
#   'Brickell',
#   'and',
#   'the',
#   'New',
#   'Bohemian',
#   '(',
#   'EBATNB',
#   ')',
#   'cds',
#   ',',
#   '1988',
#   "'s",
#   ' ',
#   'Shooting',
#   'Rubberbands',
#   'at',
#   'the',
#   'Star',
#   '(',
#   'SRATS',
#   ')',
#   'be',
#   'good',
#   'than',
#   '1990',
#   "'s",
#   'Ghost',
#   'of',
#   'a',
#   ' ',
#   'Dog',
#   'or',
#   'Edie',
#   "'s",
#   '1994',
#   'solo',
#   'effort',
#   '.',
#   'On',
#   'SRAT',
#   ',',
#   'there',
#   'be',
#   '12',
#   'consistent',
#   'and',
#   ' ',
#   'original',
#   'song',
#   'with',
#   'Edie',
#   "'s",
#   'breathy',
#   'vocal',
#   'compliment',
#   'each',
#   'one',
#   '.',
#   'The',
#   ' ',
#   'music',
#   ',',
#   'lyric',
#   'and',
#   'vocal',
#   'be',
#   'what',
#   'make',
#   'this',
#   'a',
#   'stand',
#   'out',
#   'cd',
#   '.',
#   'Sometimes',
#   'the',
#   ' ',
#   'first',
#   'cd',
#   'be',
#   'the',
#   'good',
#   'from',
#   'an',
#   'artist',
#   'and',
#   'that',
#   'would',
#   'be',
#   'accurate',
#   'to',
#   'say',
#   'here',
#   '.',
#   ' ',
#   'It',
#   'have',
#   'the',
#   'hit',
#   '&',
#   'quot;What',
#   'I',
#   'Am&quot',
#   ';',
#   'and',
#   '&',
#   'quot;Circle&quot',
#   ';',
#   'plus',
#   '8',
#   'other',
#   ' ',
#   'track',
#   'that',
#   'be',
#   'just',
#   'as',
#   'good',
#   '.',
#   'A',
#   'must',
#   'have',
#   'for',
#   'any',
#   'rock',
#   'collector',
#   '.'],
#  ['The',
#   'show',
#   'still',
#   'have',
#   'plenty',
#   'with',
#   'the',
#   'hot',
#   'original',
#   ',',
#   'witch',
#   ',',
#   'and',
#   'werewolf',
#   ',',
#   'but',
#   'I',
#   'admit',
#   'I',
#   'wish',
#   'the',
#   'actress',
#   'who',
#   'play',
#   'Rebecca',
#   'have',
#   'stay',
#   'on',
#   '.'],
#  ['I',
#   'own',
#   'several',
#   'Perky',
#   'Pet',
#   'brand',
#   'feeder',
#   'and',
#   'have',
#   'enjoy',
#   'every',
#   'one',
#   'I',
#   'have',
#   'purchase',
#   '.',
#   ' ',
#   'This',
#   'one',
#   'be',
#   'make',
#   'of',
#   'metal',
#   'mesh',
#   'that',
#   'the',
#   'bird',
#   'can',
#   'ACTUALLY',
#   'fly',
#   'through',
#   'or',
#   'perch',
#   'in',
#   'the',
#   'middle',
#   'of',
#   '.',
#   ' ',
#   'Sunflower',
#   'seed',
#   'be',
#   'not',
#   'the',
#   'cheap',
#   'wild',
#   'bird',
#   'seed',
#   'on',
#   'the',
#   'market',
#   'as',
#   'I',
#   'use',
#   'mostly',
#   'chicken',
#   'scratch',
#   'grain',
#   'and',
#   'crack',
#   'corn',
#   '.',
#   'This',
#   'be',
#   'a',
#   'sturdy',
#   'and',
#   'very',
#   'well',
#   '-',
#   'build',
#   'bird',
#   'feeder',
#   'as',
#   'be',
#   'all',
#   'of',
#   'the',
#   'Perky',
#   'Pet',
#   'brand',
#   '.',
#   'Happy',
#   'Feeding',
#   '!'],
#  ['I',
#   'usually',
#   'build',
#   'my',
#   'own',
#   'bluebird',
#   'house',
#   ',',
#   'but',
#   'time',
#   'be',
#   'at',
#   'a',
#   'premium',
#   'lately',
#   ',',
#   'so',
#   'I',
#   'could',
#   "n't",
#   'make',
#   'them',
#   '.',
#   'I',
#   'purchase',
#   'two',
#   'of',
#   'these',
#   'base',
#   'on',
#   'other',
#   'user',
#   'review',
#   '.',
#   'I',
#   'be',
#   "n't",
#   'disappoint',
#   '.',
#   'The',
#   'house',
#   'arrive',
#   'in',
#   'a',
#   'prompt',
#   'manner',
#   'and',
#   'be',
#   'well',
#   '-',
#   'build',
#   'with',
#   'a',
#   'ventilation',
#   'slit',
#   'at',
#   'the',
#   'top',
#   'of',
#   'house',
#   '.',
#   'House',
#   'open',
#   'at',
#   'the',
#   'front',
#   'for',
#   'both',
#   'easy',
#   'cleaning',
#   'and',
#   'viewing',
#   '.',
#   'I',
#   'put',
#   'them',
#   'up',
#   'just',
#   'a',
#   'few',
#   'week',
#   'ago',
#   ',',
#   'late',
#   'in',
#   'the',
#   'season',
#   ',',
#   'so',
#   'I',
#   'do',
#   "n't",
#   'anticipate',
#   'see',
#   'any',
#   'visitor',
#   ',',
#   'but',
#   'anything',
#   'be',
#   'possible',
#   '.',
#   'Just',
#   'a',
#   'couple',
#   'of',
#   'month',
#   'ago',
#   ',',
#   'two',
#   'pair',
#   'of',
#   'blue',
#   'bird',
#   'set',
#   'up',
#   'housekeeping',
#   'in',
#   'our',
#   'Purple',
#   'Martin',
#   'house',
#   ',',
#   'so',
#   ',',
#   'again',
#   ',',
#   'anything',
#   'be',
#   'possible',
#   '.',
#   'I',
#   'plan',
#   'on',
#   'buy',
#   'two',
#   'much',
#   ',',
#   'as',
#   'I',
#   'want',
#   'to',
#   'set',
#   'up',
#   'a',
#   'bluebird',
#   'trail',
#   'in',
#   'the',
#   'future',
#   '.',
#   'The',
#   'price',
#   'be',
#   'much',
#   'than',
#   'I',
#   'want',
#   'to',
#   'pay',
#   ',',
#   'but',
#   'a',
#   'lot',
#   'less',
#   'than',
#   'some',
#   'other',
#   'up',
#   'for',
#   'sale',
#   '.'],
#  ['You',
#   'would',
#   'think',
#   'that',
#   'by',
#   'the',
#   'time',
#   'I',
#   'have',
#   'go',
#   'through',
#   'year',
#   'of',
#   'try',
#   'to',
#   'deny',
#   'Tori',
#   'Amos',
#   "'s",
#   'obvious',
#   'gift',
#   'for',
#   'musical',
#   'seduction',
#   'and',
#   'manipulation',
#   ',',
#   'I',
#   'would',
#   'have',
#   'be',
#   'eager',
#   'to',
#   'get',
#   'this',
#   'album',
#   ',',
#   'but',
#   'no',
#   ',',
#   'once',
#   'much',
#   'I',
#   'have',
#   'to',
#   'be',
#   'convince',
#   'that',
#   'it',
#   'be',
#   'worth',
#   'my',
#   'while',
#   '!',
#   'Of',
#   'course',
#   'as',
#   'soon',
#   'as',
#   'I',
#   'listen',
#   'to',
#   'a',
#   'cassette',
#   'of',
#   'it',
#   ',',
#   'I',
#   'run',
#   'right',
#   'out',
#   'and',
#   'buy',
#   'it',
#   '.',
#   'But',
#   'why',
#   'do',
#   'someone',
#   'as',
#   'gifted',
#   'as',
#   'Tori',
#   'constantly',
#   'have',
#   'to',
#   'prove',
#   'herself',
#   'to',
#   'me',
#   '?',
#   'Ca',
#   "n't",
#   'I',
#   'take',
#   'her',
#   'word',
#   'for',
#   'it',
#   'yet',
#   '?',
#   'Well',
#   ',',
#   'now',
#   ',',
#   'I',
#   'can',
#   ',',
#   'but',
#   'it',
#   'take',
#   'a',
#   'long',
#   'time',
#   'to',
#   'trust',
#   'that',
#   'she',
#   'would',
#   'solidly',
#   'provide',
#   'the',
#   'kind',
#   'of',
#   'entertainment',
#   'I',
#   'only',
#   'dream',
#   'of',
#   '...',
#   'lush',
#   'musical',
#   'arrangement',
#   ',',
#   'her',
#   'unique',
#   ',',
#   'gorgeous',
#   'vocal',
#   ',',
#   'and',
#   'her',
#   'arguably',
#   'bizarre',
#   'lyric',
#   '...',
#   'well',
#   ',',
#   'I',
#   'finally',
#   'trust',
#   'that',
#   'all',
#   'these',
#   'thing',
#   'will',
#   'consistently',
#   'be',
#   'there',
#   '.',
#   'And',
#   'despite',
#   'any',
#   'change',
#   'and',
#   'incarnation',
#   'in',
#   'Tori',
#   "'s",
#   'musical',
#   'style',
#   ',',
#   'her',
#   'album',
#   'have',
#   'be',
#   'consistently',
#   'brilliant',
#   '.',
#   'We',
#   'can',
#   'credit',
#   'her',
#   'magnificent',
#   'songwriting',
#   'talent',
#   'with',
#   'this',
#   'consistency',
#   '.',
#   'Sometimes',
#   'consistency',
#   'be',
#   'boring',
#   ',',
#   'with',
#   'flash',
#   'in',
#   'the',
#   'pan',
#   'artist',
#   'who',
#   'find',
#   'a',
#   'niche',
#   'and',
#   'then',
#   'try',
#   'to',
#   'record',
#   'album',
#   'after',
#   'album',
#   'in',
#   'the',
#   'same',
#   'genre',
#   '.',
#   'Tori',
#   'have',
#   'never',
#   'do',
#   'this',
#   '.',
#   'She',
#   'easily',
#   'could',
#   'have',
#   'skate',
#   'by',
#   'on',
#   'make',
#   'Little',
#   'Earthquake',
#   'over',
#   'and',
#   'over',
#   'and',
#   'over',
#   '...',
#   'fan',
#   'would',
#   'have',
#   'be',
#   'happy',
#   'for',
#   'a',
#   'long',
#   'while',
#   '.',
#   'But',
#   'the',
#   'music',
#   'and',
#   'experience',
#   'be',
#   'much',
#   'important',
#   'to',
#   'Tori',
#   'Amos',
#   '.',
#   'Overall',
#   'this',
#   'have',
#   'make',
#   'her',
#   'much',
#   'beloved',
#   'to',
#   'her',
#   'fan',
#   'and',
#   'have',
#   'give',
#   'her',
#   'credibility',
#   'in',
#   'a',
#   'world',
#   'of',
#   'people',
#   'who',
#   'be',
#   'content',
#   'to',
#   'get',
#   'by',
#   'on',
#   'very',
#   'little',
#   'talent',
#   'and',
#   'expensive',
#   'marketing',
#   '.',
#   'I',
#   'have',
#   'to',
#   'say',
#   'that',
#   'this',
#   'album',
#   'feel',
#   'absolutely',
#   'complete',
#   'with',
#   'every',
#   'song',
#   'be',
#   'equally',
#   'brilliant',
#   'and',
#   'wonderful',
#   'from',
#   'begin',
#   'to',
#   'end',
#   '.',
#   '"',
#   'Spark',
#   '"',
#   ',',
#   '"',
#   'Cruel',
#   '"',
#   ',',
#   '"',
#   'Pandora',
#   "'s",
#   'Aquarium',
#   '"',
#   ',',
#   'and',
#   '"',
#   'Northern',
#   'Lad',
#   '"',
#   'be',
#   'all',
#   'beautiful',
#   'song',
#   '...',
#   'and',
#   'all',
#   'quite',
#   'move',
#   '.',
#   'But',
#   'despite',
#   'the',
#   'strength',
#   'of',
#   'each',
#   'song',
#   ',',
#   'the',
#   'whole',
#   'package',
#   'be',
#   'infinitely',
#   'satisfying',
#   'and',
#   'beautiful',
#   '.'],
#  ['Always',
#   'be',
#   'a',
#   'fan',
#   'of',
#   'this',
#   'hot',
#   'mess',
#   '!',
#   'This',
#   'song',
#   'make',
#   'me',
#   'wanna',
#   'speed',
#   'down',
#   'the',
#   'road',
#   'in',
#   'my',
#   'wreck',
#   'of',
#   'a',
#   'car'],
#  ['This',
#   'series',
#   'be',
#   'entertain',
#   'to',
#   'a',
#   'point',
#   '.',
#   ' ',
#   'The',
#   'altruistic',
#   'theme',
#   'be',
#   'a',
#   'little',
#   'too',
#   'thick',
#   'and',
#   'tend',
#   'to',
#   'slow',
#   'the',
#   'real',
#   'plot',
#   '.',
#   ' ',
#   'The',
#   'altruistic',
#   'line',
#   'always',
#   'bog',
#   '-',
#   'down',
#   'the',
#   'story',
#   'and',
#   'seem',
#   'to',
#   'always',
#   'take',
#   'up',
#   'so',
#   'much',
#   'of',
#   'the',
#   'air',
#   'time',
#   'the',
#   'viewer',
#   'get',
#   'bored',
#   'and',
#   'want',
#   'to',
#   'leave',
#   'the',
#   'show',
#   '!',
#   ' ',
#   'Other',
#   'than',
#   'that',
#   'it',
#   'be',
#   'worth',
#   'the',
#   'time',
#   'spend',
#   'to',
#   'watch',
#   '!',
#   ' ',
#   'The',
#   'theme',
#   'and',
#   'plot',
#   'be',
#   'well',
#   'write',
#   'and',
#   'act',
#   'out',
#   '.',
#   ' ',
#   'The',
#   'amateur',
#   '-',
#   'spy',
#   'aspect',
#   'play',
#   'just',
#   'right',
#   'as',
#   'to',
#   'enhance',
#   'the',
#   'historical',
#   'setting',
#   'and',
#   'event',
#   '.',
#   ' ',
#   'Conflict',
#   'be',
#   'abundant',
#   'and',
#   'help',
#   'overcome',
#   'the',
#   'altruistic',
#   'bog',
#   '.'],
#  ['It',
#   'be',
#   'a',
#   'good',
#   'album',
#   '.',
#   ' ',
#   'I',
#   "'ll",
#   'give',
#   'it',
#   'that',
#   '.',
#   ' ',
#   'Every',
#   'song',
#   'have',
#   'something',
#   'in',
#   'itself',
#   'that',
#   'make',
#   'them',
#   'good',
#   'song',
#   '.',
#   ' ',
#   'They',
#   'all',
#   'seem',
#   'paradoxical',
#   'to',
#   'be',
#   'place',
#   'side',
#   '-',
#   'by',
#   '-',
#   'side',
#   ',',
#   'though',
#   '.',
#   ' ',
#   'Maybe',
#   'that',
#   'be',
#   'how',
#   'Depeche',
#   'Mode',
#   'be',
#   '.',
#   ' ',
#   'They',
#   "'ve",
#   'always',
#   'be',
#   'some',
#   'what',
#   'enigmatic',
#   '.',
#   'Theme',
#   'on',
#   'this',
#   'CD',
#   'range',
#   'from',
#   'romance',
#   'to',
#   'bondage',
#   'to',
#   'parody',
#   'sappy',
#   'love',
#   'song',
#   'to',
#   'social',
#   'justice',
#   '.',
#   ' ',
#   'Every',
#   'song',
#   'on',
#   'this',
#   'CD',
#   'be',
#   'good',
#   '.',
#   ' ',
#   'I',
#   'just',
#   'question',
#   'the',
#   'fact',
#   'that',
#   'all',
#   'these',
#   'song',
#   'be',
#   'so',
#   'different',
#   'from',
#   'each',
#   'other',
#   '.'],
#  ['I',
#   'have',
#   'several',
#   'leather',
#   'handbag',
#   'that',
#   'have',
#   'a',
#   'glaze',
#   'coating',
#   'and',
#   'I',
#   'find',
#   'this',
#   'product',
#   'work',
#   'BEST',
#   'for',
#   'that',
#   'leather',
#   'type',
#   '.',
#   'Just',
#   'like',
#   'some',
#   'reviewer',
#   'point',
#   'out',
#   ',',
#   'yes',
#   ',',
#   'it',
#   'be',
#   'a',
#   'bit',
#   'sticky',
#   'and',
#   'you',
#   'do',
#   'have',
#   'to',
#   'make',
#   'sure',
#   'to',
#   'wipe',
#   'off',
#   'any',
#   'excess',
#   ',',
#   'otherwise',
#   'there',
#   'will',
#   'be',
#   'some',
#   'residue',
#   '.',
#   'I',
#   'use',
#   'this',
#   'product',
#   'in',
#   'conjunction',
#   'with',
#   'the',
#   'WhooHoo',
#   '-',
#   'Clean',
#   'foaming',
#   'saddle',
#   ',',
#   'Foaming',
#   'Saddle',
#   'Soap',
#   '.',
#   'White',
#   'Foam',
#   ',',
#   'No',
#   'Yellow',
#   'Residue',
#   'To',
#   'Worry',
#   '.',
#   'It',
#   'Clean',
#   'Without',
#   'Scratching',
#   '.',
#   'Gentle',
#   ',',
#   'Non',
#   '-',
#   'dry',
#   ',',
#   'Formulate',
#   'for',
#   'Fine',
#   '/',
#   'Luxury',
#   'Smooth',
#   'Leather',
#   '.',
#   '5',
#   'FL',
#   'OZ',
#   '.',
#   'By',
#   'WhooHoo',
#   '-',
#   'Clean',
#   'Leather',
#   'Care',
#   '.',
#   'Trust',
#   'By',
#   'Master',
#   'Cobblers.,which',
#   'work',
#   'wonder',
#   'on',
#   'stain',
#   'and',
#   'jeans',
#   "'",
#   'dye',
#   'and',
#   'their',
#   'leather',
#   'conditioner',
#   'and',
#   'clean',
#   'in',
#   'one',
#   'be',
#   'great',
#   'for',
#   'smooth',
#   'regular',
#   'or',
#   'soft',
#   'leather',
#   '.',
#   'Both',
#   'brand',
#   ',',
#   'a',
#   'must',
#   '-',
#   'have',
#   'for',
#   'everyone',
#   'who',
#   'love',
#   'their',
#   'fine',
#   'leather',
#   'item',
#   '.'],
#  ['I',
#   'find',
#   'a',
#   'Ford',
#   '6.0L',
#   'diesel',
#   'price',
#   'so',
#   'low',
#   'I',
#   'could',
#   "n't",
#   'pass',
#   ',',
#   'and',
#   ',',
#   'I',
#   'know',
#   'beforehand',
#   'it',
#   "'d",
#   'require',
#   'certain',
#   'upgrade',
#   'to',
#   'instill',
#   'natural',
#   'diesel',
#   'longevity',
#   'and',
#   'I',
#   'need',
#   'a',
#   'tool',
#   'to',
#   'help',
#   '-',
#   'enter',
#   'Scangauge',
#   'II.Scangauge',
#   'II',
#   'have',
#   'feature',
#   'beyond',
#   'a',
#   'simple',
#   'scan',
#   'tool',
#   ',',
#   'eg',
#   'Trip',
#   'Computer',
#   '(',
#   'Miles',
#   'per',
#   'Gallon',
#   ';',
#   'Tank',
#   '-',
#   'to',
#   '-',
#   'Empty',
#   ';',
#   'Cost',
#   'per',
#   'Trip',
#   ')',
#   ',',
#   'Horsepower',
#   ',',
#   '-Mile',
#   'Time',
#   ',',
#   '0',
#   '-',
#   '60',
#   'mph',
#   'Wot',
#   ',',
#   'Stop',
#   'Distance',
#   'and',
#   'other',
#   '...',
#   'Neat',
#   'feature',
#   'but',
#   'not',
#   'reason',
#   'I',
#   'purchase',
#   '...',
#   'Digital',
#   'Gauges',
#   '(',
#   'reason',
#   ')',
#   ':',
#   'the',
#   'Mfr',
#   'refer',
#   'to',
#   'this',
#   'feature',
#   'as',
#   '"',
#   'X',
#   '-',
#   'Gauge"-',
#   'Screen',
#   'display',
#   'four',
#   'real',
#   '-',
#   'time',
#   'On',
#   '-',
#   'board',
#   'diagnostic',
#   'Parameter',
#   'Identification',
#   '(',
#   'OBDII',
#   'Pid',
#   ')',
#   'of',
#   'user',
#   'choosing-',
#   'Pid',
#   'display',
#   'can',
#   'be',
#   'change',
#   'via',
#   'press',
#   'adjacent',
#   'buttons-',
#   'Performance',
#   'Data',
#   '(',
#   'MPG',
#   ',',
#   'Qtr',
#   'Mile',
#   'Time',
#   'etc',
#   ')',
#   'may',
#   'be',
#   'display',
#   'together',
#   '/',
#   'alongside',
#   'PIDs-',
#   'Displays',
#   'vehicle',
#   'mfr',
#   'generic',
#   'Pid',
#   'automatically',
#   '(',
#   'gasoline',
#   'engine)-',
#   'Displays',
#   'diesel',
#   'mfr',
#   'Pid',
#   '(',
#   'ie',
#   'EOT',
#   ',',
#   'ICT',
#   ',',
#   'IPR',
#   'etc',
#   ')',
#   'after',
#   'user',
#   'create',
#   'an',
#   "'",
#   'x',
#   '-',
#   'gauge',
#   "'",
#   'by',
#   'input',
#   'data',
#   'from',
#   'Scangauge',
#   'websiteWith',
#   'basic',
#   'knowledge',
#   'and',
#   'study',
#   'I',
#   'use',
#   'this',
#   'gadget',
#   'to',
#   'my',
#   'advantage',
#   ',',
#   'I',
#   'mean',
#   'either',
#   'repair',
#   'vehicle',
#   'myself',
#   ',',
#   'or',
#   ',',
#   'know',
#   'what',
#   'be',
#   'wrong',
#   '(',
#   'exactly',
#   'what',
#   'be',
#   'broken',
#   ')',
#   'beforehand',
#   ',',
#   'to',
#   'preclude',
#   'somename',
#   'repair',
#   'shop',
#   'rip',
#   'me',
#   'off',
#   '-',
#   'it',
#   'be',
#   'way',
#   'too',
#   'common',
#   '.',
#   'I',
#   'think',
#   'it',
#   'come',
#   'ready',
#   'to',
#   'troubleshoot',
#   'gasoline',
#   'engine',
#   ',',
#   'in',
#   'general',
#   ',',
#   'yet',
#   'I',
#   "'d",
#   'to',
#   'enter',
#   'math',
#   'data',
#   '(',
#   'avail',
#   'on',
#   'website',
#   ')',
#   'manually',
#   'for',
#   'it',
#   'to',
#   'sense',
#   'and',
#   'display',
#   'Pid',
#   'unique',
#   'to',
#   'diesel',
#   '.',
#   'After',
#   'several',
#   'day',
#   'of',
#   'study',
#   '/',
#   'application',
#   ',',
#   'my',
#   'opinion',
#   'be',
#   'this',
#   'tool',
#   'will',
#   'help',
#   'diagnose',
#   'with',
#   'near',
#   'certainty',
#   ',',
#   'component',
#   'which',
#   'have',
#   'fail',
#   'and',
#   'component',
#   'in',
#   'early',
#   'stage',
#   'of',
#   'failure',
#   '.',
#   ' ',
#   'Its',
#   'ability',
#   'to',
#   'depict',
#   'four',
#   'Pid',
#   'simultaneously',
#   'in',
#   'real',
#   '-',
#   'time',
#   'allow',
#   'comparison',
#   'between',
#   'what',
#   'related',
#   'Pid',
#   'reflect',
#   'per',
#   'desire',
#   'and',
#   'actual',
#   '.',
#   'Also',
#   'note',
#   'I',
#   'find',
#   'much',
#   'big',
#   'name',
#   'Tuners',
#   'boasting',
#   'scan',
#   'ability',
#   'do',
#   'not',
#   'monitor',
#   '/',
#   'depict',
#   'many',
#   'key',
#   'Pid',
#   'as',
#   'Scangauge',
#   ',',
#   'a',
#   'huge',
#   'shortcoming',
#   'for',
#   'tuner',
#   'price',
#   '.',
#   'Simply',
#   'put',
#   ',',
#   'the',
#   'Scangauge',
#   'II',
#   'be',
#   'much',
#   'much',
#   'than',
#   'an',
#   'OBDII',
#   'code',
#   'reader',
#   'and',
#   ',',
#   'it',
#   "'ll",
#   'be',
#   'difficult',
#   '/',
#   'near',
#   'impossible',
#   'to',
#   'find',
#   'an',
#   'item',
#   'offering',
#   'same',
#   'diagnostic',
#   'capability',
#   'for',
#   'both',
#   'gas',
#   'and',
#   'diesel',
#   'engine',
#   'at',
#   'price',
#   '.',
#   'Update',
#   'Jan',
#   '2014',
#   ':',
#   'I',
#   "'ve",
#   'purchase',
#   'another',
#   'for',
#   'my',
#   'Boy',
#   "'s",
#   'pickup',
#   'with',
#   'a',
#   '7.3L.',
#   ' ',
#   'We',
#   'both',
#   'have',
#   'SCT',
#   'Livewire',
#   '9600',
#   'Tuner',
#   'but',
#   'due',
#   'to',
#   'Livewire',
#   '9600',
#   "'s",
#   'monitoring',
#   'limitation',
#   'we',
#   'have',
#   'Scangauge',
#   'connect',
#   'full',
#   'time',
#   'to',
#   'monitor',
#   'key',
#   'Pid',
#   '.',
#   'Kyle'],
#  ['these',
#   'have',
#   'work',
#   'great',
#   'when',
#   'I',
#   "'ve",
#   'need',
#   'to',
#   'have',
#   '1/4',
#   'input',
#   'vs',
#   'the',
#   'xlr',
#   '......',
#   'especially',
#   'when',
#   'I',
#   'bust',
#   'out',
#   'the',
#   'old',
#   'Tascam',
#   '4',
#   'track',
#   'cassette',
#   '...',
#   'some',
#   'time',
#   'I',
#   'like',
#   'record',
#   'drum',
#   'analog',
#   'versus',
#   'digital',
#   'or',
#   'other',
#   'instrument'],
#  ['My',
#   'eight',
#   'year',
#   'old',
#   'grandson',
#   'and',
#   'I',
#   'enjoy',
#   'watch',
#   'these',
#   'episode',
#   'together',
#   '.',
#   'He',
#   'love',
#   'learn',
#   'about',
#   'the',
#   'swamp',
#   ',',
#   'gator',
#   ',',
#   'other',
#   'wildlife',
#   ',',
#   'and',
#   'much',
#   'of',
#   'all',
#   'the',
#   'hardy',
#   'man',
#   'and',
#   'woman',
#   'who',
#   'call',
#   'this',
#   'watery',
#   'untamed',
#   'land',
#   'home',
#   '.',
#   'So',
#   'do',
#   'I',
#   ',',
#   'thank',
#   'to',
#   'him',
#   '.'],
#  ['This',
#   'product',
#   'be',
#   'well',
#   'make',
#   'and',
#   'work',
#   'well',
#   ';',
#   'however',
#   'attempt',
#   'to',
#   'clean',
#   'both',
#   'the',
#   'bottle',
#   'and',
#   'the',
#   'base',
#   'be',
#   'very',
#   'difficult',
#   '.',
#   'The',
#   'base',
#   'be',
#   'seal',
#   'and',
#   'with',
#   'many',
#   'small',
#   'hard',
#   'to',
#   'reach',
#   'space',
#   'inside',
#   'I',
#   'ca',
#   "n't",
#   'see',
#   'how',
#   'it',
#   'can',
#   'be',
#   'clean',
#   '.',
#   'The',
#   'neck',
#   'of',
#   'the',
#   'bottle',
#   'be',
#   'very',
#   'narrow',
#   '.',
#   'Even',
#   'with',
#   'a',
#   'bottle',
#   'brush',
#   'it',
#   'be',
#   'hard',
#   'to',
#   'reach',
#   'all',
#   'the',
#   'area',
#   'inside',
#   '.'],
#  ['I',
#   'find',
#   'it',
#   'amazing',
#   'that',
#   'an',
#   'album',
#   'can',
#   'be',
#   'so',
#   'strong',
#   'without',
#   'one',
#   'bass',
#   'line',
#   'throughout',
#   'its',
#   'entirety',
#   '.',
#   ' ',
#   'This',
#   'duo',
#   'can',
#   'do',
#   'it',
#   'all',
#   '.',
#   ' ',
#   'You',
#   'want',
#   'straight',
#   'out',
#   'rock',
#   '?',
#   ' ',
#   'It',
#   'be',
#   'there',
#   '.',
#   ' ',
#   'You',
#   'want',
#   'acoustic',
#   '?',
#   ' ',
#   'It',
#   'be',
#   'there',
#   '.',
#   ' ',
#   'You',
#   'want',
#   'blue',
#   '?',
#   ' ',
#   'It',
#   'be',
#   'there',
#   '...',
#   'I',
#   'think',
#   'you',
#   'get',
#   'the',
#   'point',
#   '.',
#   ' ',
#   'Jack',
#   'White',
#   'be',
#   'a',
#   'great',
#   'guitarist',
#   ',',
#   'as',
#   'he',
#   'prove',
#   'time',
#   'and',
#   'time',
#   'again',
#   'on',
#   'this',
#   'album',
#   '.',
#   ' ',
#   'Need',
#   'proof',
#   '?',
#   ' ',
#   'Listen',
#   'closely',
#   'to',
#   '&',
#   'quot;Dead',
#   'Leave',
#   'and',
#   'the',
#   'Dirty',
#   'Ground&quot',
#   ';',
#   'or',
#   '&',
#   'quot;I',
#   'think',
#   'I',
#   'smell',
#   'a',
#   'rat.&quot',
#   ';',
#   ' ',
#   'On',
#   '&',
#   "quot;I'm",
#   'finding',
#   'it',
#   'hard',
#   'to',
#   'be',
#   'a',
#   'gentlemen&quot',
#   ';',
#   'he',
#   'begin',
#   'to',
#   'channel',
#   'Neil',
#   'Young',
#   'and',
#   'Crazy',
#   'Horse',
#   '.',
#   ' ',
#   'One',
#   'downside',
#   ',',
#   'which',
#   'actually',
#   'be',
#   'also',
#   'an',
#   'upside',
#   ',',
#   'Meg',
#   "'s",
#   'drumming',
#   'be',
#   'less',
#   'than',
#   'spectacular',
#   '.',
#   ' ',
#   'But',
#   'this',
#   'be',
#   'the',
#   'exact',
#   'type',
#   'of',
#   'drum',
#   'need',
#   'to',
#   'bring',
#   'out',
#   'the',
#   'slicing',
#   'sound',
#   'of',
#   'the',
#   'guitar',
#   '.'],
#  ['As',
#   'with',
#   'all',
#   'Masterpiece',
#   'film',
#   '-',
#   'this',
#   'be',
#   'very',
#   'good',
#   '.',
#   ' ',
#   'I',
#   'grow',
#   'up',
#   'in',
#   'Africa',
#   'and',
#   'can',
#   'say',
#   'that',
#   'it',
#   'be',
#   'very',
#   'authentic',
#   ';',
#   ' ',
#   'both',
#   'the',
#   'story',
#   'and',
#   'the',
#   'scenery',
#   '.',
#   ' ',
#   'It',
#   'be',
#   'very',
#   'representative',
#   'of',
#   'the',
#   'era',
#   '.',
#   ' ',
#   'I',
#   'enjoy',
#   'the',
#   'passion',
#   'and',
#   'sense',
#   'of',
#   'unprejudiced',
#   'justice',
#   'show',
#   'by',
#   'Superintendent',
#   'Albert',
#   'Tyburn',
#   '.',
#   ' ',
#   'Definitely',
#   'worth',
#   'watch',
#   ',',
#   'but',
#   'not',
#   'for',
#   'child',
#   '.'],
#  ['This',
#   'device',
#   'do',
#   'what',
#   'the',
#   'description',
#   'say',
#   'Build',
#   'in',
#   'air',
#   'compressor',
#   'with',
#   'cable',
#   'to',
#   'inflate',
#   'tire',
#   '.',
#   'Also',
#   'come',
#   'with',
#   'pin',
#   'to',
#   'inflate',
#   'bike',
#   ',',
#   'sport',
#   'ball',
#   'and',
#   'such.-',
#   'Jumper',
#   'cable',
#   '(',
#   'have',
#   'not',
#   'try',
#   'yet',
#   'but',
#   'will',
#   'update',
#   'review',
#   'when',
#   'the',
#   'need',
#   'arise',
#   'to',
#   'use',
#   'cables)/-',
#   'Also',
#   'come',
#   'with',
#   'USB',
#   'and',
#   'A',
#   '/',
#   'C',
#   'port',
#   'for',
#   'charge',
#   'devices.-',
#   'Do',
#   'not',
#   'come',
#   'with',
#   'a',
#   'extension',
#   'cord',
#   'to',
#   'charge',
#   'device',
#   ',',
#   'and',
#   'the',
#   'plug',
#   'be',
#   'locate',
#   'tightly',
#   'behind',
#   'unit',
#   '.',
#   'This',
#   'device',
#   'be',
#   'great',
#   'for',
#   'inflate',
#   'tire',
#   'and',
#   'just',
#   'like',
#   'a',
#   'good',
#   'air',
#   'compressor',
#   'it',
#   'come',
#   'with',
#   'a',
#   'build',
#   'in',
#   'psi',
#   'measure',
#   'to',
#   'keep',
#   'track',
#   'on',
#   'the',
#   'pressure',
#   'in',
#   'the',
#   'tire',
#   'as',
#   'you',
#   'be',
#   'inflate',
#   'them',
#   '.',
#   'This',
#   'be',
#   'a',
#   'very',
#   'heavy',
#   'item',
#   'even',
#   'for',
#   'me',
#   'be',
#   'a',
#   'young',
#   'male',
#   '.',
#   'Please',
#   'note',
#   'that',
#   'you',
#   'MUST',
#   'charge',
#   'this',
#   'device',
#   'for',
#   '24',
#   'hour',
#   'BEFORE',
#   'use',
#   'it',
#   '.',
#   'Failure',
#   'to',
#   'do',
#   'so',
#   'accord',
#   'to',
#   'the',
#   'manufacture',
#   'instruction',
#   'can',
#   'damage',
#   'the',
#   'item',
#   '.',
#   'It',
#   'seem',
#   'to',
#   'be',
#   'very',
#   'durable',
#   'and',
#   'perfect',
#   'for',
#   'the',
#   'good',
#   'Samaritan',
#   'or',
#   'the',
#   'strand',
#   'guy',
#   'or',
#   'gal',
#   'at',
#   'the',
#   'side',
#   'of',
#   'the',
#   'road',
#   '.',
#   'I',
#   'will',
#   'give',
#   'much',
#   'information',
#   'as',
#   'I',
#   'use',
#   'this',
#   'device',
#   '.',
#   'I',
#   'hope',
#   'this',
#   'review',
#   'help',
#   'and',
#   'please',
#   'give',
#   'it',
#   'a',
#   'thumb',
#   'up',
#   'if',
#   'it',
#   'help',
#   'you',
#   '.',
#   'Thank',
#   '.'],
#  ['Never',
#   'be',
#   'one',
#   'who',
#   'would',
#   'spoil',
#   'a',
#   'party',
#   '(',
#   'and',
#   'in',
#   'this',
#   'case',
#   'a',
#   'Bossa',
#   'Nova',
#   'party',
#   'at',
#   'that',
#   '!',
#   ')',
#   'critique',
#   'Antonio',
#   'Jobim',
#   "'s",
#   '"',
#   'Wave',
#   '"',
#   'should',
#   'be',
#   'a',
#   "'",
#   'labor',
#   '-',
#   'of',
#   '-',
#   'love',
#   "'",
#   'for',
#   'me',
#   '.',
#   'Anyone',
#   'peruse',
#   'my',
#   'back',
#   'catalogue',
#   'of',
#   'review',
#   'here',
#   '[',
#   '...',
#   ']',
#   'will',
#   'have',
#   'no',
#   'doubt',
#   'notice',
#   'of',
#   'my',
#   'affection',
#   'for',
#   'Mr.',
#   'Jobim',
#   'and',
#   'the',
#   'Bossa',
#   'Nova',
#   'style',
#   'that',
#   'he',
#   'almost',
#   'single',
#   'handidly',
#   'create',
#   'back',
#   'in',
#   'the',
#   'late',
#   'fifty',
#   'with',
#   'Stan',
#   'Getz',
#   '(',
#   'see',
#   '"',
#   'Girl',
#   'From',
#   'Ipanema',
#   '"',
#   ')',
#   '.',
#   'And',
#   'his',
#   'work',
#   'with',
#   'singer',
#   'Astrud',
#   'Gilberto',
#   'still',
#   'rank',
#   'extremely',
#   'high',
#   'on',
#   'my',
#   'desert',
#   'island',
#   'disc',
#   'compilation',
#   '.',
#   'I',
#   'find',
#   'his',
#   'work',
#   'with',
#   'these',
#   'artist',
#   ',',
#   'plus',
#   'Sinatra',
#   "'s",
#   'fine',
#   'album',
#   'with',
#   'Antonio',
#   ',',
#   'to',
#   'be',
#   'almost',
#   'flawless',
#   '.',
#   'High',
#   'praise',
#   'indeed',
#   '!',
#   'But',
#   ',',
#   'with',
#   'that',
#   'be',
#   'say',
#   '....',
#   'I',
#   'can',
#   'not',
#   'say',
#   'with',
#   'any',
#   'real',
#   'truthfulness',
#   'what',
#   'I',
#   'be',
#   'expect',
#   'from',
#   '"',
#   'Wave',
#   '"',
#   'but',
#   ',',
#   'while',
#   'I',
#   'still',
#   'enjoy',
#   'the',
#   'cd',
#   'immensely',
#   ',',
#   'I',
#   'find',
#   'that',
#   'I',
#   'be',
#   'leave',
#   'ask',
#   'myself',
#   '...',
#   '"',
#   'be',
#   'that',
#   'all',
#   'there',
#   'be',
#   '?',
#   '"',
#   'Again',
#   ',',
#   'I',
#   'truly',
#   'respect',
#   'the',
#   'work',
#   'of',
#   'this',
#   'amazing',
#   'Brazilian',
#   'composer',
#   'but',
#   ',',
#   'unfortunatey',
#   ',',
#   'much',
#   'of',
#   'what',
#   'be',
#   'perform',
#   'here',
#   'sound',
#   'perilously',
#   'close',
#   'to',
#   'a',
#   'sort',
#   'of',
#   "'",
#   'lounge',
#   "'",
#   'music',
#   ',',
#   'albeit',
#   'excellent',
#   'lounge',
#   'music',
#   'at',
#   'that',
#   '!',
#   'The',
#   'tune',
#   'themselves',
#   'be',
#   'wonderfully',
#   'melodic',
#   'and',
#   'harmonically',
#   'very',
#   'interesting',
#   'as',
#   'well',
#   'but',
#   ',',
#   'in',
#   'the',
#   'end',
#   ',',
#   'after',
#   'a',
#   'few',
#   'listen',
#   ',',
#   'there',
#   'be',
#   'not',
#   'much',
#   'here',
#   'that',
#   'leave',
#   'any',
#   'last',
#   'impression',
#   'on',
#   'me',
#   '.',
#   'Perhaps',
#   'I',
#   'should',
#   'chalk',
#   'this',
#   'up',
#   'to',
#   'my',
#   '1',
#   ')',
#   'be',
#   'an',
#   'innocent',
#   'when',
#   'it',
#   'come',
#   'to',
#   'understand',
#   'the',
#   'compositional',
#   'aspect',
#   'and',
#   'the',
#   'skill',
#   'involve',
#   'in',
#   'the',
#   'performing',
#   'of',
#   'music',
#   'or',
#   '2',
#   ')',
#   'my',
#   'simply',
#   'have',
#   'a',
#   "'",
#   'tin',
#   'ear',
#   "'",
#   '!',
#   'I',
#   'guess',
#   'it',
#   'be',
#   'probably',
#   'both',
#   '.',
#   'I',
#   'wo',
#   "n't",
#   'deny',
#   'that',
#   'there',
#   'be',
#   'probably',
#   'much',
#   'much',
#   'go',
#   'on',
#   'here',
#   'that',
#   'I',
#   'be',
#   'sadly',
#   'miss',
#   'and',
#   'maybe',
#   'with',
#   'time',
#   'I',
#   "'ll",
#   'be',
#   'able',
#   'to',
#   'pick',
#   'up',
#   'on',
#   'the',
#   'nuance',
#   'that',
#   'fill',
#   'this',
#   'album',
#   'but',
#   '....',
#   'Again',
#   ',',
#   'while',
#   'I',
#   'enjoy',
#   'the',
#   'cd',
#   'very',
#   'much',
#   'it',
#   'do',
#   'leave',
#   'me',
#   'with',
#   'that',
#   'martini',
#   '-',
#   'soak',
#   ',',
#   'cha',
#   '-',
#   'cha',
#   '-',
#   'cha',
#   'feeling',
#   ',',
#   'ala',
#   'Henry',
#   'Mancini',
#   'style',
#   ',',
#   'that',
#   'be',
#   'prevelant',
#   'in',
#   'the',
#   'early',
#   'sixty',
#   '.',
#   'Fortunately',
#   'though',
#   'I',
#   'still',
#   'enjoy',
#   '(',
#   'and',
#   'somewhat',
#   'subscribe',
#   ')',
#   'to',
#   'that',
#   'lifestyle',
#   'very',
#   'much',
#   ',',
#   'thank',
#   '-',
#   'you!Overall',
#   ',',
#   'while',
#   'though',
#   'this',
#   'review',
#   'be',
#   'less',
#   'than',
#   'sterling',
#   'I',
#   'would',
#   'still',
#   'heartily',
#   'recommend',
#   'add',
#   '"',
#   'Wave',
#   '"',
#   'to',
#   'your',
#   'own',
#   'collection',
#   '.',
#   'I',
#   'still',
#   'admire',
#   'Antonio',
#   'Jobim',
#   'but',
#   ',',
#   'for',
#   'me',
#   'at',
#   'less',
#   ',',
#   'I',
#   'suspect',
#   'he',
#   'will',
#   'be',
#   'all',
#   'the',
#   'well',
#   'appreciate',
#   'when',
#   'his',
#   'work',
#   'be',
#   'perform',
#   'by',
#   'other',
#   'talented',
#   'singer',
#   'as',
#   'well',
#   '.',
#   'As',
#   'for',
#   'myself',
#   ',',
#   'I',
#   'have',
#   'find',
#   'that',
#   "'",
#   'shuffle',
#   "'",
#   'this',
#   'fine',
#   'disc',
#   'with',
#   'Sinatra',
#   "'s",
#   'incredible',
#   'cd',
#   'with',
#   'Jobim',
#   'and',
#   'perhaps',
#   'throw',
#   'in',
#   'one',
#   'of',
#   'Astrud',
#   "'s",
#   'release',
#   "'s",
#   '(',
#   'see',
#   '"',
#   'Her',
#   'Fine',
#   'Hour',
#   '"',
#   ')',
#   'seem',
#   'to',
#   'work',
#   ',',
#   'in',
#   'tandem',
#   ',',
#   'very',
#   'well',
#   'together',
#   '.',
#   'It',
#   'truly',
#   'set',
#   'the',
#   'mood',
#   'for',
#   'a',
#   'wonderfully',
#   'relaxing',
#   ',',
#   'bachelor',
#   ',',
#   'devil',
#   '-',
#   'may',
#   '-',
#   'care',
#   'sort',
#   'of',
#   'evening',
#   'that',
#   'be',
#   'hard',
#   'to',
#   'deny',
#   '.',
#   'Mr.',
#   'Jobim',
#   'have',
#   'much',
#   'than',
#   'prove',
#   'himself',
#   'to',
#   'be',
#   'a',
#   'virtuoso',
#   'performer',
#   '/',
#   'composer',
#   'and',
#   'I',
#   'would',
#   "n't",
#   'try',
#   'to',
#   'change',
#   'that',
#   'legacy',
#   'for',
#   'a',
#   'moment',
#   '.',
#   'So',
#   'enjoy',
#   'and',
#   'perhaps',
#   'give',
#   'me',
#   'a',
#   'pass',
#   'thought',
#   'when',
#   'you',
#   'pour',
#   'that',
#   'first',
#   'martini',
#   '!',
#   'Mmmm',
#   '....',
#   'now',
#   'all',
#   'I',
#   'need',
#   'be',
#   'to',
#   'find',
#   'be',
#   'those',
#   'silk',
#   'pajamas',
#   '!'],
#  ['Great',
#   'little',
#   'tooland',
#   'very',
#   'handy',
#   ',',
#   'a',
#   'bargain',
#   'and',
#   'a',
#   'good',
#   'buy',
#   'Do',
#   'not',
#   'mar',
#   'my',
#   'guitar',
#   'and',
#   'be',
#   'easy',
#   'to',
#   'see',
#   ',',
#   'Thank'],
#  ['I',
#   'own',
#   'several',
#   'Charger',
#   '/',
#   'maintainer',
#   ',',
#   'and',
#   'due',
#   'to',
#   'the',
#   'affordable',
#   'price',
#   ',',
#   'it',
#   'make',
#   'since',
#   'to',
#   'purchase',
#   '.',
#   'Since',
#   'it',
#   'do',
#   'a',
#   'fine',
#   'job',
#   'of',
#   'maintaininga',
#   'decent',
#   '6V',
#   'or',
#   '12v',
#   'battery',
#   ',',
#   'even',
#   'when',
#   'it',
#   'be',
#   'drain',
#   'of',
#   'juice',
#   '.'],
#  ['When',
#   'I',
#   'first',
#   'open',
#   'this',
#   'little',
#   'feeder',
#   ',',
#   'I',
#   'be',
#   'a',
#   'bit',
#   'disappointed',
#   'in',
#   'how',
#   'small',
#   'it',
#   'be',
#   'and',
#   'how',
#   'lightweight',
#   'it',
#   'be',
#   '.',
#   ' ',
#   'I',
#   'find',
#   'the',
#   'chain',
#   'hold',
#   'it',
#   'a',
#   'little',
#   'short',
#   'as',
#   'well',
#   '.',
#   ' ',
#   'The',
#   'plastic',
#   'will',
#   'not',
#   'last',
#   'long',
#   'in',
#   'our',
#   'Southwest',
#   'as',
#   'the',
#   'sun',
#   'will',
#   'crack',
#   'it',
#   ',',
#   'even',
#   'with',
#   'it',
#   'place',
#   'in',
#   'the',
#   'shade',
#   'of',
#   'my',
#   'front',
#   '-',
#   'yard',
#   'tree',
#   '.',
#   ' ',
#   'We',
#   'do',
#   'get',
#   'a',
#   'species',
#   'of',
#   'oriole',
#   'here',
#   ',',
#   'but',
#   'much',
#   'prominent',
#   'be',
#   'the',
#   'Mexican',
#   'jay',
#   '.',
#   'The',
#   'big',
#   'disappointment',
#   'for',
#   'me',
#   'be',
#   'that',
#   'jelly',
#   'melt',
#   'fast',
#   'and',
#   'create',
#   'a',
#   'mess',
#   '.',
#   ' ',
#   'Arizona',
#   'be',
#   'currently',
#   'experience',
#   'triple',
#   '-',
#   'digit',
#   'heat',
#   ',',
#   'so',
#   'everything',
#   'melt',
#   '.',
#   ' ',
#   'The',
#   'sweet',
#   'mess',
#   'attract',
#   'ant',
#   'as',
#   'well',
#   '.',
#   'I',
#   'clean',
#   'the',
#   'plastic',
#   'container',
#   'and',
#   'put',
#   'in',
#   'large',
#   'seed',
#   'instead',
#   '.',
#   ' ',
#   'We',
#   'get',
#   'a',
#   'lot',
#   'of',
#   'cardinal',
#   'and',
#   'they',
#   'seem',
#   'to',
#   'appreciate',
#   'the',
#   'food',
#   '.',
#   ' ',
#   'I',
#   "'ll",
#   'use',
#   'this',
#   'as',
#   'a',
#   'jelly',
#   'holder',
#   'in',
#   'the',
#   'fall',
#   'and',
#   'winter',
#   '.'],
#  ['TYRANT',
#   'be',
#   'a',
#   'new',
#   'television',
#   'series',
#   'that',
#   'will',
#   'doubtless',
#   'polarize',
#   'the',
#   'viewer',
#   'who',
#   'tune',
#   'in',
#   'to',
#   'see',
#   'it',
#   '.',
#   'It',
#   'pose',
#   'many',
#   'question',
#   '-',
#   'not',
#   'only',
#   'about',
#   'Middle',
#   'East',
#   'government',
#   'but',
#   'also',
#   'an',
#   'East',
#   '/',
#   'West',
#   'attitude',
#   'split',
#   'between',
#   'member',
#   'of',
#   'a',
#   'Middle',
#   'Eastern',
#   'family',
#   ',',
#   'a',
#   'hint',
#   'about',
#   'same',
#   'sex',
#   'relationship',
#   'in',
#   'a',
#   'country',
#   'where',
#   'the',
#   'topic',
#   'be',
#   'taboo',
#   '(',
#   'watch',
#   'close',
#   'the',
#   'interplay',
#   'between',
#   'the',
#   'son',
#   'of',
#   'the',
#   '`',
#   'American',
#   "'",
#   'family',
#   'and',
#   'the',
#   'son',
#   'of',
#   'the',
#   'security',
#   'chief',
#   ')',
#   ',',
#   'and',
#   'flashback',
#   'that',
#   'emphasize',
#   'the',
#   'manipulative',
#   'takeover',
#   'of',
#   'regime',
#   'that',
#   'seem',
#   'to',
#   'be',
#   'in',
#   'constant',
#   'flux',
#   '-',
#   'depend',
#   'on',
#   'which',
#   'order',
#   'of',
#   'Muslim',
#   'be',
#   'in',
#   'power',
#   'and',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'Islamic',
#   'people',
#   '.',
#   'The',
#   'Pasadena',
#   ',',
#   'California',
#   'Al',
#   'Fayeed',
#   'family',
#   '-pediatrician',
#   'father',
#   'Barry',
#   '(',
#   'Adam',
#   'Rayner',
#   ')',
#   ',',
#   'mother',
#   'Molly',
#   '(',
#   'Jennifer',
#   'Finnigan',
#   ')',
#   ',',
#   'son',
#   'Sammy',
#   '(',
#   'Noah',
#   'Silver',
#   ')',
#   ',',
#   'daughter',
#   'Emma',
#   '(',
#   'Anna',
#   'Winter',
#   ')',
#   'be',
#   'call',
#   'back',
#   'to',
#   'the',
#   'unidentified',
#   'country',
#   'in',
#   'the',
#   'Middle',
#   'East',
#   'for',
#   'a',
#   'relative',
#   "'s",
#   'wedding',
#   '-',
#   'a',
#   'demand',
#   'from',
#   'Barry',
#   "'s",
#   'government',
#   'head',
#   'father',
#   '(',
#   'Raad',
#   'Rawl',
#   ')',
#   'and',
#   'support',
#   'by',
#   'Barry',
#   "'s",
#   'evil',
#   'brother',
#   'Jamal',
#   '(',
#   'Ashraf',
#   'Barhom',
#   ')',
#   '.',
#   'Barry',
#   'leave',
#   'his',
#   'country',
#   'and',
#   'family',
#   'at',
#   'age',
#   '16',
#   'for',
#   'reason',
#   'of',
#   'disbelief',
#   'in',
#   'his',
#   'family',
#   "'s",
#   'conduct',
#   'and',
#   'another',
#   'memory',
#   'that',
#   'surface',
#   '.',
#   'There',
#   'be',
#   'fight',
#   ',',
#   'killing',
#   ',',
#   'mayhem',
#   ',',
#   'sex',
#   ',',
#   'nudity',
#   ',',
#   'elaborate',
#   'set',
#   'and',
#   'suspense',
#   'that',
#   'keep',
#   'the',
#   'first',
#   'episode',
#   'afloat',
#   'for',
#   'an',
#   'opener',
#   '.',
#   'Some',
#   'acting',
#   'be',
#   'fine',
#   ',',
#   'other',
#   'barely',
#   'professional',
#   '.',
#   'It',
#   'will',
#   'take',
#   'several',
#   'much',
#   'episode',
#   'to',
#   'see',
#   'how',
#   'much',
#   'the',
#   'show',
#   'and',
#   'the',
#   'audience',
#   'can',
#   'tolerate',
#   '.',
#   'It',
#   'seem',
#   'like',
#   'an',
#   'attempt',
#   'to',
#   'open',
#   'window',
#   'into',
#   'the',
#   'crisis',
#   'in',
#   'the',
#   'Middle',
#   'East',
#   ',',
#   'but',
#   'it',
#   'leave',
#   'the',
#   'shutter',
#   'close',
#   'for',
#   'the',
#   'much',
#   'part',
#   '.',
#   'Keep',
#   'the',
#   'subtitle',
#   'on',
#   'if',
#   'you',
#   'care',
#   'to',
#   'identify',
#   'the',
#   'name',
#   'of',
#   'the',
#   'character',
#   '....',
#   'Grady',
#   'Harp',
#   ',',
#   'July',
#   '14'],
#  ['It',
#   'be',
#   'an',
#   'ok',
#   'sophmore',
#   'album',
#   'from',
#   'bank',
#   ',',
#   'It',
#   'wasent',
#   'as',
#   'good',
#   'as',
#   'hunger',
#   'for',
#   'much',
#   'but',
#   'its',
#   'still',
#   'worth',
#   'listen',
#   ',',
#   'bank',
#   'be',
#   'still',
#   'the',
#   'punchline',
#   'king',
#   '.'],
#  ['It',
#   'can',
#   'be',
#   'quite',
#   'hard',
#   'to',
#   'get',
#   'a',
#   'compost',
#   'pile',
#   'going',
#   '.',
#   'We',
#   'have',
#   'try',
#   'a',
#   'couple',
#   'different',
#   'way',
#   'and',
#   'could',
#   "n't",
#   'really',
#   'get',
#   'what',
#   'you',
#   'be',
#   'suppose',
#   'to',
#   'get',
#   'from',
#   'a',
#   'compost',
#   'pile',
#   ',',
#   'we',
#   'would',
#   'always',
#   'end',
#   'up',
#   'with',
#   'just',
#   'garbage',
#   'and',
#   'fly',
#   '.',
#   'We',
#   'research',
#   'online',
#   'and',
#   'watch',
#   'a',
#   'lot',
#   'of',
#   'video',
#   '.',
#   'It',
#   'have',
#   'to',
#   'have',
#   'a',
#   'certain',
#   'mixture',
#   'of',
#   'type',
#   'of',
#   'thing',
#   'that',
#   'you',
#   'add',
#   '.',
#   'We',
#   'have',
#   'way',
#   'too',
#   'much',
#   'household',
#   'food',
#   'in',
#   'ours',
#   '.',
#   'We',
#   'also',
#   'decide',
#   'to',
#   'forgo',
#   'our',
#   'compost',
#   'bin',
#   'and',
#   'decide',
#   'to',
#   'go',
#   'with',
#   'a',
#   'tumbler',
#   'composter',
#   'after',
#   'a',
#   'couple',
#   'fail',
#   'attempt',
#   'in',
#   'our',
#   'bin',
#   '.',
#   'This',
#   'Ringer',
#   'Compost',
#   'Plus',
#   'help',
#   'get',
#   'your',
#   'compost',
#   'go',
#   '.',
#   'We',
#   'be',
#   'now',
#   'have',
#   'much',
#   'good',
#   'luck',
#   '.',
#   'I',
#   'suggest',
#   'do',
#   'some',
#   'research',
#   'yourself',
#   'if',
#   'you',
#   'be',
#   'just',
#   'begin',
#   '.',
#   'There',
#   'be',
#   'much',
#   'to',
#   'compost',
#   'than',
#   'just',
#   'throw',
#   'your',
#   'scrap',
#   'and',
#   'coffee',
#   'ground',
#   'into',
#   'a',
#   'bin',
#   '.',
#   'Spring',
#   'be',
#   'the',
#   'perfect',
#   'time',
#   'to',
#   'start',
#   'and',
#   'the',
#   'Compost',
#   'Plus',
#   'give',
#   'it',
#   'a',
#   'head',
#   'start',
#   '.'],
#  ['UPDATE',
#   '9/22/13',
#   ':',
#   ' ',
#   'I',
#   "'ve",
#   'be',
#   'use',
#   'this',
#   'since',
#   'May',
#   '2013',
#   ',',
#   'and',
#   'soon',
#   'it',
#   "'ll",
#   'be',
#   'time',
#   'to',
#   'put',
#   'it',
#   'away',
#   'for',
#   'another',
#   'one',
#   'of',
#   'New',
#   'England',
#   "'s",
#   'cruel',
#   'winter',
#   '.',
#   ' ',
#   'But',
#   'before',
#   'I',
#   'do',
#   ',',
#   'I',
#   'want',
#   'to',
#   'say',
#   'that',
#   'the',
#   'auto',
#   'feed',
#   'continue',
#   'to',
#   'work',
#   'well',
#   ',',
#   'and',
#   'I',
#   'be',
#   'still',
#   'on',
#   'the',
#   'original',
#   'spool',
#   'that',
#   'come',
#   'with',
#   'the',
#   'GH710',
#   'even',
#   'after',
#   'frequent',
#   'use',
#   'throughout',
#   'the',
#   'summer',
#   '.',
#   ' ',
#   'All',
#   'in',
#   'all',
#   ',',
#   'I',
#   'would',
#   "n't",
#   'change',
#   'a',
#   'thing',
#   'in',
#   'my',
#   'review',
#   'of',
#   'June',
#   '3',
#   ',',
#   '2013',
#   'that',
#   'appear',
#   'below',
#   '.',
#   'The',
#   '$',
#   '30',
#   'trimmer',
#   'I',
#   'want',
#   'be',
#   "n't",
#   'readily',
#   'available',
#   ',',
#   'so',
#   'I',
#   'accept',
#   'the',
#   'store',
#   "'s",
#   'offer',
#   'to',
#   'sell',
#   'me',
#   'the',
#   '$',
#   '50',
#   'GH710',
#   'for',
#   '$',
#   '30',
#   'instead',
#   '.',
#   ' ',
#   'It',
#   'be',
#   "n't",
#   'until',
#   'I',
#   'get',
#   'home',
#   'that',
#   'I',
#   'see',
#   'the',
#   'negative',
#   'review',
#   ',',
#   'but',
#   'I',
#   'decide',
#   'to',
#   'give',
#   'the',
#   'trimmer',
#   'a',
#   'try',
#   'anyway',
#   '.',
#   'This',
#   'trim',
#   'and',
#   'edge',
#   'my',
#   'front',
#   ',',
#   'back',
#   ',',
#   'and',
#   'side',
#   'yard',
#   '.',
#   ' ',
#   'The',
#   '710',
#   'be',
#   'powerful',
#   ',',
#   'well',
#   'balanced',
#   ',',
#   'and',
#   'the',
#   'telescoping',
#   'handle',
#   'be',
#   'a',
#   'plus',
#   '.',
#   ' ',
#   'Also',
#   ',',
#   'its',
#   'light',
#   'weight',
#   'make',
#   'it',
#   'easy',
#   'for',
#   'a',
#   'petite',
#   'person',
#   'like',
#   'myself',
#   'to',
#   'use',
#   'for',
#   'extended',
#   'period',
#   'of',
#   'time',
#   '.',
#   ' ',
#   'This',
#   'convert',
#   'easily',
#   'to',
#   'an',
#   'edge',
#   'and',
#   'do',
#   'an',
#   'impressive',
#   'job',
#   '.',
#   'The',
#   'auto',
#   'feed',
#   'work',
#   'well',
#   ',',
#   'and',
#   'there',
#   'have',
#   'be',
#   'no',
#   'issue',
#   'with',
#   'tangle',
#   'line',
#   '.',
#   ' ',
#   'I',
#   'always',
#   'use',
#   'the',
#   'flower',
#   'guide',
#   'near',
#   'fence',
#   ',',
#   'paver',
#   ',',
#   'etc',
#   '.',
#   ',',
#   'which',
#   'give',
#   'me',
#   'a',
#   'precision',
#   'trim',
#   'and',
#   'prevent',
#   'line',
#   'breakage',
#   '.',
#   ' ',
#   'I',
#   'buy',
#   'the',
#   'GH710',
#   'at',
#   'a',
#   'good',
#   'price',
#   'point',
#   ',',
#   'it',
#   'have',
#   'all',
#   'the',
#   'feature',
#   'I',
#   'want',
#   ',',
#   'and',
#   'I',
#   'be',
#   'keep',
#   'my',
#   'finger',
#   'cross',
#   '.'],
#  ['Sarah',
#   'McLachlan',
#   "'s",
#   '2003',
#   'album',
#   '"',
#   'Afterglow',
#   '"',
#   'have',
#   'be',
#   'criticize',
#   'by',
#   'some',
#   'for',
#   'lack',
#   'good',
#   'song',
#   '.',
#   'People',
#   'who',
#   'feel',
#   'this',
#   'way',
#   'should',
#   'give',
#   'album',
#   'a',
#   'second',
#   'chance',
#   ',',
#   'because',
#   'much',
#   'of',
#   'the',
#   'song',
#   'be',
#   'really',
#   'great',
#   'and',
#   'the',
#   'album',
#   'as',
#   'a',
#   'whole',
#   'be',
#   'as',
#   'less',
#   'as',
#   'good',
#   'as',
#   'her',
#   'good',
#   '.',
#   'First',
#   'impression',
#   'may',
#   'be',
#   'that',
#   'the',
#   'song',
#   'be',
#   'generally',
#   'less',
#   'catchy',
#   'and',
#   'hard',
#   'to',
#   'get',
#   'into',
#   ',',
#   'compare',
#   'to',
#   'her',
#   'previous',
#   'album',
#   '.',
#   'Personally',
#   'I',
#   'find',
#   'both',
#   '"',
#   'Fallen',
#   '"',
#   'and',
#   '"',
#   'Push',
#   '"',
#   'very',
#   'good',
#   'and',
#   'cacthy',
#   'from',
#   'first',
#   'listen',
#   ',',
#   'while',
#   'other',
#   'song',
#   'like',
#   'the',
#   'waltzy',
#   '"',
#   'Time',
#   '"',
#   'and',
#   'the',
#   'quiet',
#   'and',
#   'beautiful',
#   '"',
#   'Answer',
#   '"',
#   'take',
#   'a',
#   'little',
#   'much',
#   'time',
#   'for',
#   'me',
#   'to',
#   'realize',
#   'how',
#   'great',
#   'song',
#   'they',
#   'be',
#   '.',
#   'The',
#   'album',
#   'be',
#   ',',
#   'at',
#   'time',
#   ',',
#   'lyrically',
#   'slightly',
#   'disillusioned',
#   'and',
#   'dark',
#   ',',
#   'but',
#   'on',
#   'the',
#   'other',
#   'hand',
#   'it',
#   'show',
#   'a',
#   'strong',
#   'belief',
#   'in',
#   'love',
#   '.',
#   'Musically',
#   'it',
#   'be',
#   'a',
#   'quiet',
#   'and',
#   'mature',
#   'album',
#   ';',
#   'like',
#   'always',
#   'well',
#   '-',
#   'produce',
#   '.'],
#  ['I',
#   'be',
#   'so',
#   'happy',
#   'that',
#   'these',
#   'guy',
#   'be',
#   'back',
#   '!',
#   'After',
#   'their',
#   'last',
#   'album',
#   ',',
#   'Pop',
#   'Trash',
#   '(',
#   'which',
#   'I',
#   'be',
#   "n't",
#   'too',
#   'crazy',
#   'about',
#   'to',
#   'say',
#   'the',
#   'less',
#   ')',
#   ',',
#   'Duran',
#   'Duran',
#   'be',
#   'back',
#   'and',
#   'good',
#   'than',
#   'ever',
#   '...',
#   'now',
#   'with',
#   'all',
#   '5',
#   'original',
#   'member',
#   '!',
#   'With',
#   'Warren',
#   'return',
#   'to',
#   'Missing',
#   'Person',
#   'and',
#   'those',
#   'other',
#   'two',
#   'what',
#   '-',
#   'his',
#   '-',
#   'face',
#   'away',
#   ',',
#   'Duran',
#   'Duran',
#   'have',
#   'filter',
#   'out',
#   'all',
#   'flaw',
#   '(',
#   'exclude',
#   'one',
#   'track',
#   ')',
#   'and',
#   'be',
#   'sound',
#   'good',
#   'than',
#   'ever!"(Reach',
#   'up',
#   'for',
#   'the',
#   ')',
#   'Sunrise',
#   '"',
#   'be',
#   'the',
#   'first',
#   'track',
#   'on',
#   'the',
#   'album',
#   ',',
#   'and',
#   'will',
#   'be',
#   'consider',
#   'the',
#   '"',
#   'Duran',
#   'Anthem',
#   '"',
#   'some',
#   'day',
#   '.',
#   'Originally',
#   'a',
#   'demo',
#   'that',
#   'have',
#   'never',
#   'see',
#   'the',
#   'light',
#   'of',
#   'an',
#   'album',
#   ',',
#   'Sunrise',
#   'be',
#   'take',
#   'out',
#   'of',
#   'the',
#   'closet',
#   ',',
#   'dust',
#   ',',
#   'and',
#   'put',
#   'back',
#   'in',
#   'action',
#   ',',
#   'now',
#   'remaster',
#   '.',
#   'I',
#   'really',
#   'like',
#   'this',
#   'song',
#   'because',
#   'of',
#   'it',
#   'be',
#   'energetic',
#   'pace',
#   '.',
#   'Not',
#   'too',
#   'fast',
#   ',',
#   'nor',
#   'slow',
#   '.',
#   'Other',
#   'honorable',
#   'mention',
#   'include',
#   '"',
#   'One',
#   'of',
#   'those',
#   'day',
#   '"',
#   ',',
#   '"',
#   'Point',
#   'of',
#   'no',
#   'return',
#   '"',
#   ',',
#   '"',
#   'Want',
#   'you',
#   'Much',
#   '!',
#   '"',
#   ',',
#   'and',
#   '"',
#   'What',
#   'happen',
#   'tomorrow',
#   '"',
#   ',',
#   'each',
#   'with',
#   'its',
#   'own',
#   'awesome',
#   '...',
#   'awesomeness',
#   '.',
#   '"',
#   'One',
#   'of',
#   'those',
#   'day',
#   '"',
#   'have',
#   'its',
#   "'",
#   'mild',
#   "'",
#   'feeling',
#   ',',
#   '"',
#   'Point',
#   'of',
#   'No',
#   'Return',
#   '"',
#   'be',
#   'a',
#   'catchy',
#   'tribute',
#   'to',
#   '9/11',
#   'song',
#   ',',
#   '"',
#   'Want',
#   'you',
#   'much',
#   '!',
#   '"',
#   'have',
#   'a',
#   'great',
#   'beat',
#   ',',
#   'plus',
#   'I',
#   'ca',
#   "n't",
#   'get',
#   'that',
#   'synth',
#   'out',
#   'of',
#   'my',
#   'mind',
#   ',',
#   'and',
#   '"',
#   'What',
#   'happen',
#   'tomorrow',
#   '"',
#   'have',
#   'a',
#   'slow',
#   ',',
#   'peaceful',
#   'feeling',
#   'which',
#   'I',
#   'enjoy',
#   'a',
#   'lot',
#   '.',
#   'Overall',
#   ',',
#   'this',
#   'album',
#   'be',
#   'great',
#   'because',
#   'it',
#   'bring',
#   'me',
#   'back',
#   'to',
#   'the',
#   '"',
#   'Seven',
#   'and',
#   'the',
#   'Ragged',
#   'Tiger',
#   '"',
#   'day',
#   'because',
#   'the',
#   'band',
#   'sound',
#   'well',
#   'together',
#   '.',
#   'Power',
#   'Station',
#   'only',
#   'have',
#   ',',
#   'like',
#   ',',
#   'one',
#   'good',
#   'song',
#   ',',
#   'Arcadia',
#   'be',
#   'awesome',
#   ',',
#   'but',
#   'it',
#   'be',
#   'a',
#   'flop',
#   ',',
#   'and',
#   'do',
#   "n't",
#   'even',
#   'remind',
#   'me',
#   'of',
#   '"',
#   'Thank',
#   'You',
#   '!',
#   '"',
#   'The',
#   'only',
#   'way',
#   'I',
#   'can',
#   'express',
#   'my',
#   'gratitude',
#   'towards',
#   'Duran',
#   'Duran',
#   'for',
#   'un',
#   '-',
#   'breaking',
#   'up',
#   'be',
#   'this',
#   ':',
#   'I',
#   'ca',
#   "n't",
#   'wait',
#   'to',
#   'hear',
#   'the',
#   'next',
#   'album',
#   '.'],
#  ['I',
#   'first',
#   'catch',
#   'the',
#   'tail',
#   'end',
#   'of',
#   'this',
#   'song',
#   'on',
#   'the',
#   'radio',
#   ',',
#   'and',
#   'I',
#   'be',
#   'insistent',
#   'upon',
#   'hear',
#   'this',
#   'song',
#   'in',
#   'its',
#   'entirety',
#   '.',
#   'This',
#   'be',
#   'such',
#   'a',
#   'great',
#   'song',
#   ',',
#   'a',
#   'very',
#   'commercial',
#   'sounding',
#   'song',
#   ',',
#   'so',
#   'hopefully',
#   'that',
#   'will',
#   'appeal',
#   'to',
#   'the',
#   'people',
#   'who',
#   'purchase',
#   'Back',
#   'to',
#   'Basic',
#   'but',
#   'decide',
#   'to',
#   'skip',
#   'out',
#   'on',
#   'Bionic',
#   '(',
#   'which',
#   'I',
#   'love',
#   ')',
#   '.',
#   'Very',
#   'catchy',
#   'but',
#   'sultry',
#   'at',
#   'the',
#   'same',
#   'time',
#   ',',
#   'and',
#   'Christina',
#   'never',
#   'fail',
#   'to',
#   'showcase',
#   'her',
#   'vocal',
#   '.',
#   'Ca',
#   "n't",
#   'wait',
#   'to',
#   'see',
#   'what',
#   'her',
#   'next',
#   'project',
#   'bring',
#   '.'],
#  ['happy',
#   'to',
#   'see',
#   'josh',
#   'back',
#   'on',
#   'TV',
#   'this',
#   'sort',
#   'of',
#   'comedy',
#   'be',
#   'not',
#   'really',
#   'my',
#   'thing',
#   'but',
#   'many',
#   'people',
#   'warm',
#   'up',
#   'to',
#   'it',
#   'the',
#   'premise',
#   'be',
#   'unique',
#   'and',
#   'could',
#   "n't",
#   'stop',
#   'laugh',
#   'the',
#   'humour',
#   'be',
#   'a',
#   'bit',
#   'broad',
#   'but',
#   'it',
#   'speak',
#   'to',
#   'an',
#   'audience',
#   'and',
#   'i',
#   'can',
#   'see',
#   'it',
#   'do',
#   'very',
#   'well',
#   '.'],
#  ['I',
#   'barely',
#   'get',
#   'through',
#   'the',
#   'first',
#   'episode',
#   '...',
#   'I',
#   'feel',
#   'like',
#   'I',
#   "'d",
#   'be',
#   'down',
#   'this',
#   'road',
#   'before',
#   ',',
#   'and',
#   'that',
#   'there',
#   'be',
#   'nothing',
#   'new',
#   'to',
#   'be',
#   'discover',
#   '.',
#   'Very',
#   'thin',
#   'on',
#   'story',
#   'I',
#   'think',
#   ',',
#   'so',
#   'I',
#   "'ll",
#   'just',
#   'have',
#   'to',
#   'watch',
#   'a',
#   'couple',
#   'much',
#   'to',
#   'see',
#   'if',
#   'this',
#   'improve',
#   'or',
#   'I',
#   'just',
#   'give',
#   'up',
#   'on',
#   'it',
#   '.',
#   'The',
#   'show',
#   'have',
#   'some',
#   'potential',
#   ',',
#   'but',
#   'I',
#   'think',
#   'it',
#   'be',
#   'box',
#   'itself',
#   'into',
#   'a',
#   'corner',
#   'story',
#   'wise',
#   '.'],
#  ['It',
#   'be',
#   'hilarious',
#   'how',
#   'people',
#   'react',
#   'and',
#   'show',
#   'off',
#   'for',
#   'something',
#   'minor',
#   'and',
#   'ridiculous',
#   'how',
#   'people',
#   'ticket',
#   'add',
#   'up',
#   'to',
#   'month',
#   'of',
#   'bill',
#   '.'],
#  ['Almost',
#   'before',
#   'we',
#   'could',
#   'walk',
#   'away',
#   'from',
#   'the',
#   'feeder',
#   ',',
#   'the',
#   'bird',
#   'come',
#   'and',
#   'feast',
#   'on',
#   'them',
#   '.',
#   'The',
#   'convenience',
#   'of',
#   'have',
#   'these',
#   'heavy',
#   'bag',
#   'of',
#   'seed',
#   'deliver',
#   'to',
#   'our',
#   'door',
#   'be',
#   'a',
#   'true',
#   'blessing',
#   '.',
#   'The',
#   'bag',
#   'be',
#   'heavy',
#   '.',
#   'The',
#   'seed',
#   'assortment',
#   'be',
#   'great',
#   'and',
#   'have',
#   'attract',
#   'mourn',
#   'dove',
#   ',',
#   'cardinal',
#   ',',
#   'finch',
#   ',',
#   'and',
#   'other',
#   'bird',
#   'we',
#   'have',
#   'yet',
#   'to',
#   'identify',
#   '.',
#   'The',
#   'feder',
#   'give',
#   'pleasure',
#   'to',
#   'the',
#   'bird',
#   'and',
#   'provide',
#   'us',
#   'with',
#   'nature',
#   "'s",
#   'entertainment',
#   '.'],
#  ['My',
#   'son',
#   'love',
#   'this',
#   'between',
#   'this',
#   'and',
#   'bubble',
#   'guppy',
#   'he',
#   'ca',
#   "n't",
#   'get',
#   'enough',
#   'and',
#   'be',
#   'actually',
#   'learn',
#   'from',
#   'watch',
#   'the',
#   'different',
#   'shoe',
#   '.',
#   ' ',
#   'Hope',
#   'the',
#   'other',
#   'season',
#   'be',
#   'offer',
#   'as',
#   'prime',
#   'soon',
#   '!'],
#  ['This',
#   'season',
#   '1',
#   'and',
#   'all',
#   'other',
#   'season',
#   'in',
#   'this',
#   'series',
#   'be',
#   'very',
#   'educative',
#   'to',
#   'watch',
#   '.',
#   'You',
#   'will',
#   'find',
#   'the',
#   'host',
#   'Mr.',
#   'Mike',
#   'Rowe&#8217;s',
#   'comment',
#   'very',
#   'entertaining',
#   '.',
#   'Mike',
#   'have',
#   'go',
#   'to',
#   'some',
#   'extraordinary',
#   'length',
#   'to',
#   'participate',
#   'in',
#   'these',
#   'series',
#   'and',
#   'show',
#   'us',
#   'an',
#   'array',
#   'of',
#   'episode',
#   'how',
#   'hard',
#   'some',
#   'honest',
#   'people',
#   'work',
#   'in',
#   'this',
#   'country',
#   'to',
# ...
#   'a',
#   'gas',
#   'mower',
#   '.',
#   'And',
#   'the',
#   'cord',
#   'be',
#   'a',
#   'big',
#   "ol'",
#   'pain',
#   'in',
#   'the',
#   'butt',
#   '.',
#   'I',
#   'be',
#   'pretty',
#   'sure',
#   'that',
#   'I',
#   'will',
#   'run',
#   'over',
#   'the',
#   'cord',
#   'at',
#   'some',
#   'point',
#   'in',
#   'this',
#   'mower',
#   "'s",
#   'life',
#   ',',
#   'and',
#   'I',
#   'be',
#   'not',
#   'look',
#   'forward',
#   'to',
#   'find',
#   'out',
#   'what',
#   'happen',
#   'when',
#   'that',
#   'happens!It',
#   'do',
#   "n't",
#   'come',
#   'with',
#   'a',
#   'cord',
#   ',',
#   'by',
#   'the',
#   'way',
#   ',',
#   'and',
#   'you',
#   'do',
#   'need',
#   'one',
#   'that',
#   'be',
#   'significantly',
#   'long',
#   'than',
#   'your',
#   'yard',
#   'for',
#   'turn',
#   'around',
#   ',',
#   'etc',
#   '.',
#   'If',
#   'you',
#   'be',
#   'willing',
#   'to',
#   'drop',
#   '$',
#   '250',
#   'for',
#   'a',
#   'lawn',
#   'mower',
#   ',',
#   'I',
#   'assume',
#   'you',
#   'be',
#   'okay',
#   'with',
#   'spend',
#   'another',
#   '$',
#   '20',
#   'or',
#   'whatever',
#   'for',
#   'a',
#   'cord',
#   ',',
#   'but',
#   'it',
#   'be',
#   'something',
#   'to',
#   'be',
#   'aware',
#   'of',
#   '.',
#   'There',
#   'be',
#   'a',
#   'nice',
#   'feature',
#   'for',
#   'keep',
#   'the',
#   'cord',
#   'securely',
#   'plug',
#   'in',
#   'to',
#   'the',
#   'mower',
#   ',',
#   'but',
#   'it',
#   'be',
#   'not',
#   'intuitive',
#   '(',
#   'I',
#   'do',
#   "n't",
#   'read',
#   'the',
#   'manual',
#   ')',
#   '.',
#   'The',
#   'bag',
#   'assembly',
#   'take',
#   'up',
#   'a',
#   'lot',
#   'of',
#   'space',
#   ',',
#   'but',
#   'hold',
#   'a',
#   'lot',
#   '.',
#   'I',
#   'have',
#   "n't",
#   'use',
#   'the',
#   'mulch',
#   ',',
#   'so',
#   'ca',
#   "n't",
#   'review',
#   'that',
#   '.',
#   'I',
#   'guess',
#   'my',
#   'big',
#   'problem',
#   'with',
#   'this',
#   'mower',
#   'be',
#   'that',
#   'it',
#   'do',
#   "n't",
#   'make',
#   'mow',
#   'the',
#   'lawn',
#   'any',
#   'less',
#   'hateful',
#   '.',
#   'The',
#   'reel',
#   'mower',
#   '*',
#   'do',
#   '*',
#   'make',
#   'it',
#   'less',
#   'hateful',
#   ',',
#   'but',
#   'you',
#   'have',
#   'to',
#   'keep',
#   'up',
#   'with',
#   'it',
#   '.',
#   'If',
#   'you',
#   'be',
#   'willing',
#   'to',
#   'do',
#   'that',
#   ',',
#   'and',
#   'have',
#   'a',
#   'small',
#   'space',
#   'to',
#   'mow',
#   ',',
#   'I',
#   "'d",
#   'recommend',
#   'a',
#   'reel',
#   'mower',
#   'over',
#   'this',
#   'one',
#   '.',
#   'If',
#   'you',
#   'have',
#   'a',
#   'big',
#   'space',
#   ',',
#   'I',
#   'would',
#   "n't",
#   'recommend',
#   'this',
#   'anyway',
#   ',',
#   'due',
#   'to',
#   'the',
#   'cord',
#   '.',
#   'If',
#   'keep',
#   'up',
#   'with',
#   'it',
#   'be',
#   "n't",
#   'feasible',
#   'for',
#   'you',
#   ',',
#   'or',
#   'not',
#   'worth',
#   'it',
#   ',',
#   'I',
#   'guess',
#   'this',
#   'offer',
#   'some',
#   'advantage',
#   'over',
#   'gas',
#   ',',
#   'but',
#   'I',
#   'be',
#   'not',
#   'ultimately',
#   'sure',
#   'it',
#   'be',
#   'worth',
#   'the',
#   'price',
#   'tag',
#   ',',
#   'especially',
#   'if',
#   'you',
#   'already',
#   'have',
#   'a',
#   'gas',
#   'mower',
#   ',',
#   'and',
#   'especially',
#   'since',
#   'find',
#   'someone',
#   'to',
#   'fix',
#   'it',
#   'if',
#   'it',
#   'break',
#   '/',
#   'stop',
#   'work',
#   'would',
#   'probably',
#   'be',
#   'quite',
#   'a',
#   'chore',
#   '.'],
#  ['Robin',
#   'Yvette',
#   'Allen',
#   '(',
#   'Or',
#   'The',
#   'Lady',
#   'Of',
#   'Rage',
#   ')',
#   'have',
#   'be',
#   'in',
#   'the',
#   'Music',
#   'business',
#   'since',
#   'Dr.',
#   'Dre',
#   'release',
#   '"',
#   'The',
#   'Chronic',
#   '"',
#   'in',
#   '1992',
#   '.',
#   'This',
#   'be',
#   'her',
#   'only',
#   'album',
#   '.',
#   'She',
#   'be',
#   'one',
#   'of',
#   'my',
#   'favorite',
#   'female',
#   'rapper',
#   '.',
#   'Where',
#   'be',
#   'she',
#   'now',
#   '?',
#   'These',
#   'day',
#   ',',
#   'I',
#   'only',
#   'see',
#   'her',
#   'on',
#   'repeat',
#   'of',
#   '"',
#   'The',
#   'Steve',
#   'Harvey',
#   'Show',
#   '"',
#   'as',
#   'Coretta',
#   '(',
#   'Thankfully',
#   ',',
#   'she',
#   'be',
#   'in',
#   'the',
#   'good',
#   'of',
#   'DVD',
#   ')',
#   '.',
#   'What',
#   'happen',
#   'to',
#   'her',
#   'music',
#   'career',
#   '?',
#   'Do',
#   'she',
#   'just',
#   'quit',
#   '?',
#   'She',
#   'really',
#   'need',
#   'to',
#   'do',
#   'another',
#   'album',
#   '.',
#   'Rage',
#   ',',
#   'Please',
#   'drop',
#   'another',
#   'album',
#   'or',
#   'as',
#   'Snoop',
#   'Dogg',
#   'would',
#   'say',
#   '"',
#   'Rage',
#   ',',
#   'would',
#   'you',
#   'please',
#   'drop',
#   'some',
#   'Gangsta',
#   'S',
#   '*',
#   '*',
#   '*',
#   '!',
#   '"'],
#  ['this',
#   'show',
#   'keep',
#   'you',
#   'on',
#   'the',
#   'edge',
#   'of',
#   'your',
#   'seat',
#   '!',
#   '!',
#   '!',
#   'so',
#   'good',
#   '!',
#   '!',
#   'we',
#   'can',
#   'not',
#   'wait',
#   'until',
#   'the',
#   'next',
#   'season'],
#  ['Be',
#   'I',
#   'mistake',
#   '?',
#   'Do',
#   'I',
#   'miss',
#   'something',
#   '?',
#   'Or',
#   'the',
#   'Fast',
#   'Eddie',
#   'Clarke',
#   'who',
#   'write',
#   'song',
#   'with',
#   'title',
#   'like',
#   '&',
#   'quot;FEEL',
#   'ME',
#   'TOUCH',
#   'ME&quot',
#   ';',
#   'and',
#   '&',
#   'quot;all',
#   'I',
#   'NEED',
#   'BE',
#   'YOUR',
#   'LOVE&quot',
#   ';',
#   'be',
#   'the',
#   'same',
#   'Eddie',
#   'Clarke',
#   'who',
#   'be',
#   'part',
#   'of',
#   'the',
#   'glorious',
#   'MOTORHEAD',
#   '?',
#   '?',
#   'Unbeliavable',
#   '...'],
#  ['I',
#   "'ve",
#   'only',
#   'try',
#   'these',
#   'outside',
#   ',',
#   'as',
#   'I',
#   'have',
#   'pet',
#   'inside',
#   'and',
#   'I',
#   'do',
#   "n't",
#   'want',
#   'the',
#   'mouse',
#   'to',
#   'eat',
#   'the',
#   'bait',
#   'and',
#   'then',
#   'die',
#   'in',
#   'the',
#   'house',
#   ',',
#   'and',
#   'then',
#   'risk',
#   'my',
#   'dog',
#   'mess',
#   'around',
#   'with',
#   'poison',
#   'dead',
#   'mouse',
#   '.',
#   'The',
#   'mouse',
#   'that',
#   'be',
#   'root',
#   'around',
#   'in',
#   'my',
#   'garden',
#   'seem',
#   'to',
#   'be',
#   'go',
#   ',',
#   'so',
#   'I',
#   'guess',
#   'it',
#   'be',
#   'be',
#   'work',
#   '.',
#   'The',
#   'Tier',
#   '1',
#   'station',
#   'mean',
#   'you',
#   'can',
#   'keep',
#   'the',
#   'plastic',
#   'bait',
#   'house',
#   '-',
#   'which',
#   'be',
#   'secure',
#   'enough',
#   'that',
#   'pet',
#   'ca',
#   "n't",
#   'get',
#   'in',
#   ',',
#   'and',
#   'replace',
#   'the',
#   'bait',
#   'brick',
#   '.',
#   ' ',
#   'Frankly',
#   ',',
#   'I',
#   'do',
#   "n't",
#   'really',
#   'want',
#   'to',
#   'be',
#   'handle',
#   'the',
#   'poison',
#   'bait',
#   '-',
#   'so',
#   'I',
#   'plan',
#   'to',
#   'throw',
#   'the',
#   'whole',
#   'thing',
#   'away',
#   'when',
#   'the',
#   'bait',
#   'be',
#   'chew',
#   'up',
#   '.',
#   'And',
#   'the',
#   'only',
#   'benefit',
#   'over',
#   'snap',
#   'trap',
#   'be',
#   'be',
#   'able',
#   'to',
#   'set',
#   'it',
#   'and',
#   'forget',
#   'it',
#   'and',
#   'not',
#   'have',
#   'to',
#   'deal',
#   'with',
#   'the',
#   'dead',
#   'mouse',
#   'after',
#   '.'],
#  ['If',
#   'you',
#   'have',
#   'vehicle',
#   'that',
#   'you',
#   'only',
#   'run',
#   'half',
#   'the',
#   'year-',
#   'a',
#   'motorcycle',
#   ',',
#   'or',
#   'a',
#   'snowmobile',
#   ',',
#   'or',
#   'a',
#   'large',
#   'outboard-',
#   'it',
#   'be',
#   'important',
#   'to',
#   'keep',
#   'the',
#   'battery',
#   'charge',
#   'during',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'year',
#   ',',
#   'or',
#   'it',
#   "'ll",
#   'self',
#   '-',
#   'discharge',
#   'and',
#   'eventually',
#   'self',
#   '-',
#   'destruct',
#   '.',
#   'The',
#   'good',
#   'way',
#   'to',
#   'keep',
#   'that',
#   'battery',
#   'fresh',
#   'be',
#   'to',
#   'bring',
#   'it',
#   'indoor',
#   'and',
#   'connect',
#   'an',
#   'intelligent',
#   'trickle',
#   'charger',
#   'that',
#   "'ll",
#   'keep',
#   'it',
#   'top',
#   'off',
#   'without',
#   'overcharge',
#   '.',
#   'I',
#   'have',
#   'a',
#   'constantly',
#   'change',
#   'collection',
#   'of',
#   'small',
#   'motorcycle',
#   'and',
#   'scooter',
#   'in',
#   'my',
#   'garage',
#   'and',
#   'a',
#   'marine',
#   'battery',
#   'that',
#   'get',
#   'use',
#   'occasionally',
#   'to',
#   'run',
#   'a',
#   'trolling',
#   'motor',
#   ',',
#   'and',
#   'to',
#   'go',
#   'with',
#   'them',
#   ',',
#   'a',
#   'small',
#   'collection',
#   'of',
#   'these',
#   'battery',
#   'tender',
#   'in',
#   'both',
#   '6',
#   'and',
#   '12',
#   'volt',
#   'model',
#   '.',
#   'They',
#   'be',
#   'not',
#   'terribly',
#   'expensive',
#   ',',
#   'and',
#   'they',
#   'work',
#   '.',
#   'You',
#   'can',
#   'also',
#   'buy',
#   'multi',
#   '-',
#   'charge',
#   'model',
#   'like',
#   'theBattery',
#   'Tender',
#   '021',
#   '-',
#   '0128',
#   'Battery',
#   'Tender',
#   'Plus',
#   '12V',
#   'Battery',
#   'Chargerthat',
#   'will',
#   'handle',
#   'from',
#   'two',
#   'to',
#   'as',
#   'many',
#   'as',
#   'ten',
#   'battery',
#   'at',
#   'once',
#   ',',
#   'and',
#   'if',
#   'you',
#   'do',
#   'have',
#   'much',
#   'than',
#   'one',
#   'battery',
#   'to',
#   'maintain',
#   ',',
#   "they'e",
#   'a',
#   'good',
#   'deal',
#   ',',
#   'and',
#   'the',
#   'high',
#   'end',
#   'model',
#   'be',
#   'also',
#   'regulate',
#   'and',
#   'temperature',
#   'control',
#   '.',
#   'If',
#   'I',
#   'be',
#   'start',
#   'from',
#   'zero',
#   'that',
#   'be',
#   'the',
#   'way',
#   'I',
#   "'d",
#   'go',
#   ',',
#   'but',
#   'I',
#   'start',
#   'with',
#   'just',
#   'one',
#   ',',
#   'and',
#   'they',
#   'be',
#   'all',
#   'still',
#   'work',
#   ',',
#   'so',
#   'I',
#   'have',
#   'no',
#   'need',
#   'to',
#   'upgrade',
#   '.'],
#  ['The',
#   'Mars',
#   'Volta',
#   'sound',
#   'like',
#   'nobody',
#   'on',
#   'earth',
#   ',',
#   'and',
#   'nobody',
#   'on',
#   'earth',
#   'sound',
#   'like',
#   'The',
#   'Mars',
#   'Volta',
#   '.',
#   'They',
#   'be',
#   'a',
#   'spastic',
#   'and',
#   'off',
#   '-',
#   'the',
#   '-',
#   'wall',
#   'group',
#   'that',
#   'cross',
#   'musical',
#   'genre',
#   'from',
#   'jazz',
#   'to',
#   'punk',
#   'to',
#   'prog',
#   'rock',
#   'to',
#   'experimentation',
#   'and',
#   'back',
#   'again',
#   '.',
#   'The',
#   'instrumentation',
#   'on',
#   'this',
#   'album',
#   'be',
#   'flawless',
#   'and',
#   'top',
#   'notch',
#   'artistry',
#   '.',
#   'The',
#   'lyric',
#   'and',
#   'vocal',
#   'be',
#   'amazing',
#   'and',
#   'will',
#   'pierce',
#   'the',
#   'very',
#   'soul',
#   'of',
#   'your',
#   'fragile',
#   'existence',
#   '.',
#   'The',
#   'vocal',
#   'range',
#   'from',
#   'beautiful',
#   'crooning',
#   'to',
#   'shriek',
#   'falsetto',
#   ',',
#   'to',
#   'lovely',
#   'rhythm',
#   '.',
#   'In',
#   'between',
#   'song',
#   ',',
#   'you',
#   'be',
#   'treat',
#   'to',
#   'electronic',
#   'dub',
#   'sounding',
#   'interlude',
#   'that',
#   'add',
#   'an',
#   'eerie',
#   'atmosphere',
#   'to',
#   'the',
#   'already',
#   'esoteric',
#   'and',
#   'mysterious',
#   'album',
#   '.',
#   'Each',
#   'song',
#   'be',
#   'a',
#   'musical',
#   'landscape',
#   'of',
#   'wonder',
#   'and',
#   'raw',
#   ',',
#   'intense',
#   'emotion',
#   'that',
#   'will',
#   'blow',
#   'you',
#   'away',
#   'and',
#   're',
#   '-',
#   'define',
#   'your',
#   'vision',
#   'of',
#   'music',
#   'and',
#   '"',
#   'acceptable',
#   '"',
#   'musical',
#   'theory',
#   '.',
#   'I',
#   'be',
#   'turn',
#   'on',
#   'to',
#   'The',
#   'Mars',
#   'Volta',
#   'through',
#   'Frances',
#   'the',
#   'Mute',
#   ',',
#   'and',
#   'a',
#   'couple',
#   'of',
#   'my',
#   'friend',
#   'pop',
#   'in',
#   'De',
#   '-',
#   'loused',
#   'and',
#   'comment',
#   '"',
#   'This',
#   'be',
#   'way',
#   'good',
#   'than',
#   'Frances',
#   'the',
#   'Mute',
#   '"',
#   '.',
#   'I',
#   'personally',
#   'disagree',
#   'with',
#   'that',
#   'statement',
#   ',',
#   'I',
#   'feel',
#   'that',
#   'Frances',
#   'the',
#   'Mute',
#   'be',
#   'good',
#   '.',
#   'But',
#   'this',
#   'moment',
#   'be',
#   'not',
#   'one',
#   'to',
#   'compare',
#   '.',
#   'This',
#   'moment',
#   'be',
#   'to',
#   'revel',
#   'in',
#   'the',
#   'glory',
#   'and',
#   'awesomness',
#   'that',
#   'be',
#   'De',
#   '-',
#   'louse',
#   'in',
#   'the',
#   'Comatorium',
#   ',',
#   'a',
#   'CD',
#   'of',
#   'utter',
#   'perfection',
#   '.',
#   'If',
#   'you',
#   'have',
#   'not',
#   'yet',
#   'hear',
#   'The',
#   'Mars',
#   'Volta',
#   ',',
#   'you',
#   'be',
#   'miss',
#   'out',
#   'on',
#   'a',
#   'true',
#   'sonic',
#   'experience',
#   'that',
#   'will',
#   'change',
#   'the',
#   'way',
#   'you',
#   'view',
#   'music',
#   'forever',
#   '.',
#   'Great',
#   'Genre',
#   'bend',
#   'prog',
#   'music',
#   'be',
#   'hard',
#   'to',
#   'come',
#   'by',
#   ',',
#   'and',
#   'many',
#   'band',
#   'try',
#   'and',
#   'fail',
#   '.',
#   'Mile',
#   'Davis',
#   'have',
#   'it',
#   'perfect',
#   ',',
#   'if',
#   'not',
#   'do',
#   'the',
#   'strange',
#   'and',
#   'much',
#   'wack',
#   'out',
#   'version',
#   'of',
#   'it',
#   '.',
#   'The',
#   'Mars',
#   'Volta',
#   'have',
#   'perfect',
#   'it',
#   'and',
#   'our',
#   'generation',
#   'be',
#   'good',
#   'because',
#   'of',
#   'it',
#   '.',
#   'If',
#   'your',
#   'wondering',
#   'which',
#   'Mars',
#   'Volta',
#   'album',
#   'to',
#   'pick',
#   'up',
#   'first(De',
#   '-',
#   'louse',
#   'or',
#   'Fance',
#   'the',
#   'Mute',
#   ')',
#   ',',
#   'De',
#   '-',
#   'loused',
#   'be',
#   'the',
#   'much',
#   '"',
#   'normal',
#   '"',
#   'of',
#   'the',
#   'two',
#   '.',
#   'And',
#   'when',
#   'I',
#   'say',
#   'normal',
#   'I',
#   'mean',
#   'the',
#   'album',
#   'with',
#   'less',
#   'experimentation',
#   'and',
#   'much',
#   'regular',
#   'musical',
#   'structure',
#   '.',
#   'Frances',
#   'might',
#   'scare',
#   'you',
#   'away',
#   ',',
#   'but',
#   'if',
#   'your',
#   'into',
#   'a',
#   'heavily',
#   'laden',
#   ',',
#   'sonic',
#   'concept',
#   'album',
#   'of',
#   'massive',
#   'proportion',
#   ',',
#   'then',
#   'pick',
#   'up',
#   'Frances',
#   'the',
#   'Mute',
#   'first',
#   '.',
#   'It',
#   'do',
#   "n't",
#   'really',
#   'matter',
#   ',',
#   'because',
#   'I',
#   'know',
#   'that',
#   'you',
#   'will',
#   'eventually',
#   'pick',
#   'up',
#   'everything',
#   'that',
#   'The',
#   'Mars',
#   'Volta',
#   'have',
#   'to',
#   'offer',
#   '....',
#   'just',
#   'wait',
#   'until',
#   'you',
#   'hear',
#   'Amputecture',
#   '......'],
#  ['The',
#   'spirit',
#   'of',
#   'the',
#   'wild',
#   'West',
#   'live',
#   'on',
#   ',',
#   'in',
#   'this',
#   'compelling',
#   'package',
#   'of',
#   'modern',
#   'cowboy',
#   'song',
#   '.',
#   'I',
#   'be',
#   'immediately',
#   'draw',
#   'into',
#   'the',
#   'scene',
#   ',',
#   'as',
#   'the',
#   'opening',
#   'chord',
#   'of',
#   '"',
#   'I',
#   "'d",
#   'Rather',
#   'Be',
#   'A',
#   'Cowboy',
#   '"',
#   'step',
#   'boldly',
#   'from',
#   'my',
#   'speaker',
#   '.',
#   'I',
#   "'ve",
#   'always',
#   'think',
#   'this',
#   'song',
#   'deserve',
#   'much',
#   'attention',
#   'and',
#   'airplay',
#   'than',
#   'it',
#   'get',
#   'when',
#   'it',
#   'be',
#   'release',
#   '.',
#   '"',
#   'River',
#   'Of',
#   'Love',
#   '"',
#   'and',
#   '"',
#   'Whiskey',
#   'Basin',
#   'Blue',
#   '"',
#   'be',
#   'perfectly',
#   'execute',
#   ',',
#   'stereotypical',
#   'western',
#   'song',
#   'about',
#   'love',
#   'go',
#   'cold',
#   '.',
#   'John',
#   "'s",
#   'love',
#   'of',
#   'nature',
#   'appear',
#   'once',
#   'again',
#   'in',
#   'top',
#   'form',
#   ',',
#   'on',
#   'the',
#   'georgeous',
#   '"',
#   'Rocky',
#   'Mountain',
#   'Suite',
#   '(',
#   'Cold',
#   'Night',
#   'In',
#   'Canada',
#   ')',
#   '"',
#   '.',
#   'The',
#   'innocence',
#   'of',
#   'childhood',
#   'be',
#   'beautifully',
#   'weave',
#   'into',
#   '"',
#   'Zachary',
#   '&',
#   'Jennifer',
#   '"',
#   ',',
#   'a',
#   'wistful',
#   'ballad',
#   'sing',
#   'to',
#   'John',
#   "'s",
#   'unborn',
#   'child',
#   ',',
#   'with',
#   'an',
#   'oboe',
#   'and',
#   'a',
#   'recorder',
#   'dancing',
#   'elegantly',
#   'together',
#   'at',
#   'the',
#   'end',
#   '.',
#   '"',
#   'Sweet',
#   'Misery',
#   '"',
#   'be',
#   'a',
#   'tongue',
#   '-',
#   'in',
#   '-',
#   'cheek',
#   'blue',
#   'number',
#   'that',
#   'greet',
#   'the',
#   'hard',
#   'knock',
#   'of',
#   'life',
#   'with',
#   'hopeful',
#   'determination',
#   '.',
#   'However',
#   ',',
#   'not',
#   'every',
#   'tune',
#   'here',
#   'resonate',
#   'with',
#   'me',
#   '.',
#   'There',
#   'be',
#   'a',
#   'couple',
#   'of',
#   '"',
#   'skipper',
#   '"',
#   ',',
#   'as',
#   'I',
#   'call',
#   'them',
#   '.',
#   '"',
#   'Berkely',
#   'Woman',
#   '"',
#   'be',
#   'a',
#   'skirt',
#   '-',
#   'chaser',
#   "'s",
#   'anthem',
#   ',',
#   'feature',
#   'the',
#   'line',
#   ',',
#   '"',
#   'A',
#   'woman',
#   'be',
#   'the',
#   'sweet',
#   'fruit',
#   'that',
#   'God',
#   'ever',
#   'put',
#   'on',
#   'the',
#   'vine',
#   '/',
#   'I',
#   "'d",
#   'no',
#   'much',
#   'love',
#   'just',
#   'one',
#   'kind',
#   'of',
#   'woman',
#   'than',
#   'drink',
#   'only',
#   'one',
#   'kind',
#   'of',
#   'wine',
#   '.',
#   '"',
#   'Rather',
#   'insult',
#   'to',
#   'monogamous',
#   'couple',
#   'everywhere',
#   '.',
#   '"',
#   'Angel',
#   'From',
#   'Montgomery',
#   '"',
#   ',',
#   'pen',
#   'by',
#   'Bonnie',
#   'Rait',
#   ',',
#   'just',
#   'sound',
#   'dull',
#   'and',
#   'ordinary',
#   'to',
#   'me',
#   '.',
#   'Have',
#   'say',
#   'that',
#   ',',
#   'I',
#   'hasten',
#   'to',
#   'add',
#   'that',
#   'I',
#   'strongly',
#   'recommend',
#   'this',
#   'album',
#   '.',
#   'After',
#   'all',
#   '.',
#   'two',
#   'skipper',
#   'and',
#   'nine',
#   'keeper',
#   'be',
#   'pretty',
#   'good',
#   '!',
#   'This',
#   'record',
#   'be',
#   'a',
#   'great',
#   'companion',
#   'for',
#   'a',
#   'road',
#   'trip',
#   'or',
#   'camping',
#   '.'],
#  ...]

# %% [markdown]
# Probaré diferentes modelos con diferentes tipos de preprocesado y al final compararé mis resultados.
#
# Comenzaré construyéndome un corpus que contenga tan solo el texto y una categoría (positivo, negativo y neutro).

# %%
reviews = reviews[['reviewText','overall']]

for ix, processed_text in zip(range(len(reviews)), preprocess_texts(reviews.reviewText)):
    reviews.reviewText[ix] = " ".join(processed_text)
    
reviews.overall = reviews.overall.apply(lambda x: 'pos' if x > 3 else 'neg' if x < 3 else 'neu')

# %% [markdown]
# Ahora me interesa hacerun split en train y test

# %%
X_train, X_test, y_train, y_test = train_test_split(
    reviews.reviewText,
    reviews.overall,
    train_size=0.80,
    test_size=0.20,
    shuffle=True
)

# %% [markdown]
# Ahora utilizaré el tf-idf de mi corpus de entrenamiento para obtener las palabras más relevantes que detectan el sentimiento y comprobar si tiene sentido.

# %%
cv = TfidfVectorizer(
    max_df=0.95,
    min_df=5,
    max_features=2500,
    strip_accents='ascii',
    ngram_range=(2, 3)
)
cv.fit(X_train)

# %%
# Compute the chi-squared score for each word in the training set and show the values
i = 15

chi2score = chi2(X_train_, y_train)[0]
scores = list(zip(cv.get_feature_names(), chi2score))
sorted_scores = sorted(scores, key=lambda x:x[1])
topchi2 = list(zip(*sorted_scores[-i:]))
x = range(len(topchi2[1]))
labels = topchi2[0]

plt.figure(figsize=(12, 8))
plt.barh(x,topchi2[1], align='center', alpha=0.5)
plt.plot(topchi2[1], x, '-o', markersize=5, alpha=0.8)
plt.yticks(x, labels, fontsize=12)
plt.xlabel('$\chi^2$', fontsize=26)
plt.ylabel('word', fontsize=16)
plt.title('Top {} $\chi^2$ score for each word in the training set'.format(i), fontsize=20)
plt.grid()
plt.tight_layout()
plt.show();
